# %%
# ! pip install absl-py
# ! pip install --upgrade google-api-python-client
# ! pip install gast
# ! pip install opt-einsum
# ! pip install astunparse
# ! pip install termcolor
# ! pip install --upgrade tensorflow

# import pkg_resources
# from subprocess import call
# packages = [dist.project_name for dist in pkg_resources.working_set]
# call("pip install --upgrade " + ' '.join(packages), shell=True)

# %% [markdown]
# # 모델 훈련 조기 종료(Early/Stopping)

# %% [markdown]
#     * MNIST&데이터 로드 후 정규화(Normalization)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist 
import numpy as np
import matplotlib.pyplot as plt
#1
(x_train, y_train), (x_test, y_test) = mnist.load_data()
#2: normalize images
x_train = x_train.astype('float32') 
x_test = x_test.astype('float32') 
x_train /= 255.0 # [0, 1] 
x_test /= 255.0

# %% [markdown]
#     * 레이블을 모두 원 핫 인코딩 벡터(One-hot encoding vector)로 변환

# %%
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
#     * 완전연결층(Dense+layer) 사용해서 다층 퍼셉트론(MLP) 모델 구축하기

# %%
#4: x_train.shape = (60000, 28, 28) 
model = tf.keras. Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28))) 
model.add(tf.keras.layers.Dense (units=5, activation='sigmoid')) 
model.add(tf.keras.layers.Dense (units=10, activation='softmax')) 
model.summary() # ← 이 코드를 사용하면 모델 구축 결과를 요약해서 볼 수 있다.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 5)                 3925
#
#  dense_1 (Dense)             (None, 10)                60
#
# =================================================================
# Total params: 3985 (15.57 KB)
# Trainable params: 3985 (15.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.RMSprop(learning_rate=0.01) # ← Setting model optimizer as RMSprop 
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
#     * 콜백 설정: 특정 조건에서 모델 조기 종료 설정

# %%
#5
callback = tf.keras.callbacks. EarlyStopping (monitor= 'val_loss', 
                                              min_delta = 0.001, #최소 갱신 값 
                                              patience=10, #위반 허용 횟수
                                              verbose=1, # Callback 메시지 출력
                                              mode = 'auto') # 'min', 'max', 'auto'

#6
# 
ret = model.fit(x_train, y_train, epochs=100, batch_size=200,
                validation_split =0.2, verbose=2, callbacks = [callback])
# Out:
# Epoch 1/100
# 240/240 - 1s - loss: 1.0800 - accuracy: 0.7356 - val_loss: 0.6295 - val_accuracy: 0.8528 - 1s/epoch - 4ms/step
# Epoch 2/100
# 240/240 - 0s - loss: 0.5593 - accuracy: 0.8514 - val_loss: 0.4983 - val_accuracy: 0.8609 - 396ms/epoch - 2ms/step
# Epoch 3/100
# 240/240 - 0s - loss: 0.4937 - accuracy: 0.8606 - val_loss: 0.4975 - val_accuracy: 0.8596 - 389ms/epoch - 2ms/step
# Epoch 4/100
# 240/240 - 0s - loss: 0.4737 - accuracy: 0.8654 - val_loss: 0.4649 - val_accuracy: 0.8674 - 387ms/epoch - 2ms/step
# Epoch 5/100
# 240/240 - 0s - loss: 0.4624 - accuracy: 0.8683 - val_loss: 0.4584 - val_accuracy: 0.8672 - 402ms/epoch - 2ms/step
# Epoch 6/100
# 240/240 - 0s - loss: 0.4582 - accuracy: 0.8679 - val_loss: 0.4638 - val_accuracy: 0.8655 - 399ms/epoch - 2ms/step
# Epoch 7/100
# 240/240 - 0s - loss: 0.4536 - accuracy: 0.8699 - val_loss: 0.4648 - val_accuracy: 0.8648 - 399ms/epoch - 2ms/step
# Epoch 8/100
# 240/240 - 0s - loss: 0.4495 - accuracy: 0.8722 - val_loss: 0.4445 - val_accuracy: 0.8712 - 384ms/epoch - 2ms/step
# Epoch 9/100
# 240/240 - 0s - loss: 0.4457 - accuracy: 0.8717 - val_loss: 0.4445 - val_accuracy: 0.8742 - 394ms/epoch - 2ms/step
# Epoch 10/100
# 240/240 - 0s - loss: 0.4431 - accuracy: 0.8723 - val_loss: 0.4425 - val_accuracy: 0.8723 - 405ms/epoch - 2ms/step
# Epoch 11/100
# 240/240 - 1s - loss: 0.4400 - accuracy: 0.8744 - val_loss: 0.4428 - val_accuracy: 0.8728 - 521ms/epoch - 2ms/step
# Epoch 12/100
# 240/240 - 1s - loss: 0.4379 - accuracy: 0.8744 - val_loss: 0.4411 - val_accuracy: 0.8720 - 553ms/epoch - 2ms/step
# Epoch 13/100
# 240/240 - 1s - loss: 0.4353 - accuracy: 0.8761 - val_loss: 0.4467 - val_accuracy: 0.8719 - 536ms/epoch - 2ms/step
# Epoch 14/100
# 240/240 - 1s - loss: 0.4331 - accuracy: 0.8754 - val_loss: 0.4460 - val_accuracy: 0.8702 - 519ms/epoch - 2ms/step
# Epoch 15/100
# 240/240 - 1s - loss: 0.4316 - accuracy: 0.8767 - val_loss: 0.4396 - val_accuracy: 0.8736 - 547ms/epoch - 2ms/step
# Epoch 16/100
# 240/240 - 1s - loss: 0.4309 - accuracy: 0.8751 - val_loss: 0.4575 - val_accuracy: 0.8669 - 527ms/epoch - 2ms/step
# Epoch 17/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 10
#       2 callback = tf.keras.callbacks. EarlyStopping (monitor= 'val_loss',
#       3                                               min_delta = 0.001, #최소 갱신 값
#       4                                               patience=10, #위반 허용 횟수
#       5                                               verbose=1, # Callback 메시지 출력
#       6                                               mode = 'auto') # 'min', 'max', 'auto'
#       8 #6
#       9 #
# ---> 10 ret = model.fit(x_train, y_train, epochs=100, batch_size=200,
#      11                 validation_split =0.2, verbose=2, callbacks = [callback])
#
# File c:\Users\nonel\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\nonel\anaconda3\Lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
#     * 모델 학습 스케쥴러 정의하기

# %%
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return 0.5 * lr
    return lr

callback = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

# 여기서 만든 Schedular() 함수는 2 에폭 간격으로 학습률을  0.1*learning rate로 감소시킨다.변화된 학습률은 다음 에폭에 반영된다.
# LearningRateSchedular(scheduler, verbose=1) 로 LearningRateSchedular 의 callback을 생성한다.

# %% [markdown]
#     * 정의한 모델 학습 스케쥴러에 따라 모델 훈련시키기

# %%
#6
# 
ret = model.fit(x_train, y_train, epochs=100, batch_size=200,
                validation_split =0.2, verbose=2, callbacks = [callback])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 1/100
# 240/240 - 1s - loss: 0.3610 - accuracy: 0.9004 - val_loss: 0.3978 - val_accuracy: 0.8885 - lr: 0.0100 - 675ms/epoch - 3ms/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 2/100
# 240/240 - 1s - loss: 0.3629 - accuracy: 0.8999 - val_loss: 0.4153 - val_accuracy: 0.8842 - lr: 0.0100 - 526ms/epoch - 2ms/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 3/100
# 240/240 - 1s - loss: 0.3606 - accuracy: 0.9005 - val_loss: 0.3998 - val_accuracy: 0.8894 - lr: 0.0100 - 530ms/epoch - 2ms/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 4/100
# 240/240 - 1s - loss: 0.3598 - accuracy: 0.9012 - val_loss: 0.4017 - val_accuracy: 0.8895 - lr: 0.0100 - 525ms/epoch - 2ms/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 5/100
# 240/240 - 1s - loss: 0.3591 - accuracy: 0.9008 - val_loss: 0.4229 - val_accuracy: 0.8817 - lr: 0.0100 - 557ms/epoch - 2ms/step
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 6/100
# 240/240 - 1s - loss: 0.3595 - accuracy: 0.9014 - val_loss: 0.4012 - val_accuracy: 0.8884 - lr: 0.0100 - 591ms/epoch - 2ms/step
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 7/100
# 240/240 - 1s - loss: 0.3589 - accuracy: 0.9010 - val_loss: 0.3989 - val_accuracy: 0.8878 - lr: 0.0100 - 722ms/epoch - 3ms/step
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 8/100
# 240/240 - 1s - loss: 0.3586 - accuracy: 0.9001 - val_loss: 0.3972 - val_accuracy: 0.8895 - lr: 0.0100 - 892ms/epoch - 4ms/step
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 9/100
# 240/240 - 1s - loss: 0.3581 - accuracy: 0.9010 - val_loss: 0.3946 - val_accuracy: 0.8905 - lr: 0.0100 - 709ms/epoch - 3ms/step
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 10/100
# 240/240 - 1s - loss: 0.3565 - accuracy: 0.9016 - val_loss: 0.4130 - val_accuracy: 0.8867 - lr: 0.0100 - 769ms/epoch - 3ms/step
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.004999999888241291.
# Epoch 11/100
# 240/240 - 1s - loss: 0.3405 - accuracy: 0.9076 - val_loss: 0.3925 - val_accuracy: 0.8920 - lr: 0.0050 - 735ms/epoch - 3ms/step
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.004999999888241291.
# Epoch 12/100
# 240/240 - 1s - loss: 0.3381 - accuracy: 0.9089 - val_loss: 0.3916 - val_accuracy: 0.8920 - lr: 0.0050 - 671ms/epoch - 3ms/step
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.004999999888241291.
# Epoch 13/100
# 240/240 - 1s - loss: 0.3372 - accuracy: 0.9071 - val_loss: 0.3991 - val_accuracy: 0.8875 - lr: 0.0050 - 805ms/epoch - 3ms/step
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.004999999888241291.
# Epoch 14/100
# 240/240 - 1s - loss: 0.3367 - accuracy: 0.9065 - val_loss: 0.3885 - val_accuracy: 0.8918 - lr: 0.0050 - 674ms/epoch - 3ms/step
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.004999999888241291.
# Epoch 15/100
# 240/240 - 1s - loss: 0.3364 - accuracy: 0.9076 - val_loss: 0.3964 - val_accuracy: 0.8913 - lr: 0.0050 - 629ms/epoch - 3ms/step
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.004999999888241291.
# Epoch 16/100
# 240/240 - 1s - loss: 0.3365 - accuracy: 0.9076 - val_loss: 0.3961 - val_accuracy: 0.8918 - lr: 0.0050 - 541ms/epoch - 2ms/step
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.004999999888241291.
# Epoch 17/100
# 240/240 - 1s - loss: 0.3358 - accuracy: 0.9076 - val_loss: 0.3870 - val_accuracy: 0.8917 - lr: 0.0050 - 778ms/epoch - 3ms/step
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.004999999888241291.
# Epoch 18/100
# 240/240 - 1s - loss: 0.3350 - accuracy: 0.9072 - val_loss: 0.3922 - val_accuracy: 0.8906 - lr: 0.0050 - 628ms/epoch - 3ms/step
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.004999999888241291.
# Epoch 19/100
# 240/240 - 1s - loss: 0.3351 - accuracy: 0.9077 - val_loss: 0.3999 - val_accuracy: 0.8885 - lr: 0.0050 - 598ms/epoch - 2ms/step
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.004999999888241291.
# Epoch 20/100
# 240/240 - 1s - loss: 0.3351 - accuracy: 0.9071 - val_loss: 0.3939 - val_accuracy: 0.8919 - lr: 0.0050 - 755ms/epoch - 3ms/step
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0024999999441206455.
# Epoch 21/100
# 240/240 - 1s - loss: 0.3264 - accuracy: 0.9108 - val_loss: 0.3896 - val_accuracy: 0.8911 - lr: 0.0025 - 698ms/epoch - 3ms/step
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0024999999441206455.
# Epoch 22/100
# 240/240 - 1s - loss: 0.3257 - accuracy: 0.9119 - val_loss: 0.3869 - val_accuracy: 0.8933 - lr: 0.0025 - 706ms/epoch - 3ms/step
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0024999999441206455.
# Epoch 23/100
# 240/240 - 1s - loss: 0.3256 - accuracy: 0.9110 - val_loss: 0.3897 - val_accuracy: 0.8909 - lr: 0.0025 - 703ms/epoch - 3ms/step
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0024999999441206455.
# Epoch 24/100
# 240/240 - 1s - loss: 0.3256 - accuracy: 0.9115 - val_loss: 0.3890 - val_accuracy: 0.8928 - lr: 0.0025 - 709ms/epoch - 3ms/step
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0024999999441206455.
# Epoch 25/100
# 240/240 - 1s - loss: 0.3245 - accuracy: 0.9114 - val_loss: 0.3878 - val_accuracy: 0.8943 - lr: 0.0025 - 643ms/epoch - 3ms/step
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0024999999441206455.
# Epoch 26/100
# 240/240 - 1s - loss: 0.3247 - accuracy: 0.9113 - val_loss: 0.3900 - val_accuracy: 0.8924 - lr: 0.0025 - 597ms/epoch - 2ms/step
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0024999999441206455.
# Epoch 27/100
# 240/240 - 1s - loss: 0.3245 - accuracy: 0.9111 - val_loss: 0.3904 - val_accuracy: 0.8925 - lr: 0.0025 - 858ms/epoch - 4ms/step
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0024999999441206455.
# Epoch 28/100
# 240/240 - 1s - loss: 0.3241 - accuracy: 0.9111 - val_loss: 0.3881 - val_accuracy: 0.8929 - lr: 0.0025 - 771ms/epoch - 3ms/step
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0024999999441206455.
# Epoch 29/100
# 240/240 - 1s - loss: 0.3241 - accuracy: 0.9111 - val_loss: 0.3874 - val_accuracy: 0.8918 - lr: 0.0025 - 695ms/epoch - 3ms/step
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0024999999441206455.
# Epoch 30/100
# 240/240 - 1s - loss: 0.3240 - accuracy: 0.9112 - val_loss: 0.3894 - val_accuracy: 0.8929 - lr: 0.0025 - 626ms/epoch - 3ms/step
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.0012499999720603228.
# Epoch 31/100
# 240/240 - 1s - loss: 0.3200 - accuracy: 0.9127 - val_loss: 0.3876 - val_accuracy: 0.8938 - lr: 0.0012 - 633ms/epoch - 3ms/step
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.0012499999720603228.
# Epoch 32/100
# 240/240 - 1s - loss: 0.3195 - accuracy: 0.9131 - val_loss: 0.3869 - val_accuracy: 0.8932 - lr: 0.0012 - 600ms/epoch - 3ms/step
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0012499999720603228.
# Epoch 33/100
# 240/240 - 1s - loss: 0.3193 - accuracy: 0.9131 - val_loss: 0.3865 - val_accuracy: 0.8925 - lr: 0.0012 - 578ms/epoch - 2ms/step
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.0012499999720603228.
# Epoch 34/100
# 240/240 - 1s - loss: 0.3192 - accuracy: 0.9130 - val_loss: 0.3892 - val_accuracy: 0.8931 - lr: 0.0012 - 580ms/epoch - 2ms/step
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.0012499999720603228.
# Epoch 35/100
# 240/240 - 1s - loss: 0.3189 - accuracy: 0.9129 - val_loss: 0.3872 - val_accuracy: 0.8924 - lr: 0.0012 - 553ms/epoch - 2ms/step
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0012499999720603228.
# Epoch 36/100
# 240/240 - 1s - loss: 0.3190 - accuracy: 0.9134 - val_loss: 0.3867 - val_accuracy: 0.8925 - lr: 0.0012 - 598ms/epoch - 2ms/step
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.0012499999720603228.
# Epoch 37/100
# 240/240 - 1s - loss: 0.3189 - accuracy: 0.9127 - val_loss: 0.3873 - val_accuracy: 0.8922 - lr: 0.0012 - 551ms/epoch - 2ms/step
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.0012499999720603228.
# Epoch 38/100
# 240/240 - 1s - loss: 0.3189 - accuracy: 0.9134 - val_loss: 0.3863 - val_accuracy: 0.8928 - lr: 0.0012 - 545ms/epoch - 2ms/step
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.0012499999720603228.
# Epoch 39/100
# 240/240 - 1s - loss: 0.3186 - accuracy: 0.9132 - val_loss: 0.3874 - val_accuracy: 0.8926 - lr: 0.0012 - 587ms/epoch - 2ms/step
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.0012499999720603228.
# Epoch 40/100
# 240/240 - 1s - loss: 0.3187 - accuracy: 0.9128 - val_loss: 0.3858 - val_accuracy: 0.8932 - lr: 0.0012 - 603ms/epoch - 3ms/step
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0006249999860301614.
# Epoch 41/100
# 240/240 - 1s - loss: 0.3163 - accuracy: 0.9148 - val_loss: 0.3862 - val_accuracy: 0.8942 - lr: 6.2500e-04 - 692ms/epoch - 3ms/step
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.0006249999860301614.
# Epoch 42/100
# 240/240 - 1s - loss: 0.3162 - accuracy: 0.9146 - val_loss: 0.3872 - val_accuracy: 0.8933 - lr: 6.2500e-04 - 582ms/epoch - 2ms/step
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.0006249999860301614.
# Epoch 43/100
# 240/240 - 1s - loss: 0.3160 - accuracy: 0.9143 - val_loss: 0.3863 - val_accuracy: 0.8930 - lr: 6.2500e-04 - 587ms/epoch - 2ms/step
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.0006249999860301614.
# Epoch 44/100
# 240/240 - 1s - loss: 0.3160 - accuracy: 0.9144 - val_loss: 0.3858 - val_accuracy: 0.8938 - lr: 6.2500e-04 - 644ms/epoch - 3ms/step
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.0006249999860301614.
# Epoch 45/100
# 240/240 - 1s - loss: 0.3161 - accuracy: 0.9139 - val_loss: 0.3853 - val_accuracy: 0.8936 - lr: 6.2500e-04 - 582ms/epoch - 2ms/step
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.0006249999860301614.
# Epoch 46/100
# 240/240 - 1s - loss: 0.3157 - accuracy: 0.9140 - val_loss: 0.3866 - val_accuracy: 0.8938 - lr: 6.2500e-04 - 560ms/epoch - 2ms/step
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.0006249999860301614.
# Epoch 47/100
# 240/240 - 1s - loss: 0.3157 - accuracy: 0.9147 - val_loss: 0.3871 - val_accuracy: 0.8946 - lr: 6.2500e-04 - 621ms/epoch - 3ms/step
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.0006249999860301614.
# Epoch 48/100
# 240/240 - 1s - loss: 0.3158 - accuracy: 0.9145 - val_loss: 0.3862 - val_accuracy: 0.8934 - lr: 6.2500e-04 - 559ms/epoch - 2ms/step
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.0006249999860301614.
# Epoch 49/100
# 240/240 - 1s - loss: 0.3158 - accuracy: 0.9141 - val_loss: 0.3862 - val_accuracy: 0.8943 - lr: 6.2500e-04 - 578ms/epoch - 2ms/step
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0006249999860301614.
# Epoch 50/100
# 240/240 - 1s - loss: 0.3157 - accuracy: 0.9140 - val_loss: 0.3853 - val_accuracy: 0.8929 - lr: 6.2500e-04 - 525ms/epoch - 2ms/step
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0003124999930150807.
# Epoch 51/100
# 240/240 - 1s - loss: 0.3145 - accuracy: 0.9148 - val_loss: 0.3859 - val_accuracy: 0.8938 - lr: 3.1250e-04 - 555ms/epoch - 2ms/step
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.0003124999930150807.
# Epoch 52/100
# 240/240 - 1s - loss: 0.3144 - accuracy: 0.9146 - val_loss: 0.3853 - val_accuracy: 0.8931 - lr: 3.1250e-04 - 592ms/epoch - 2ms/step
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.0003124999930150807.
# Epoch 53/100
# 240/240 - 1s - loss: 0.3144 - accuracy: 0.9151 - val_loss: 0.3860 - val_accuracy: 0.8939 - lr: 3.1250e-04 - 540ms/epoch - 2ms/step
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0003124999930150807.
# Epoch 54/100
# 240/240 - 1s - loss: 0.3144 - accuracy: 0.9147 - val_loss: 0.3857 - val_accuracy: 0.8946 - lr: 3.1250e-04 - 540ms/epoch - 2ms/step
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.0003124999930150807.
# Epoch 55/100
# 240/240 - 1s - loss: 0.3143 - accuracy: 0.9147 - val_loss: 0.3859 - val_accuracy: 0.8938 - lr: 3.1250e-04 - 551ms/epoch - 2ms/step
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0003124999930150807.
# Epoch 56/100
# 240/240 - 1s - loss: 0.3143 - accuracy: 0.9147 - val_loss: 0.3860 - val_accuracy: 0.8939 - lr: 3.1250e-04 - 650ms/epoch - 3ms/step
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.0003124999930150807.
# Epoch 57/100
# 240/240 - 1s - loss: 0.3142 - accuracy: 0.9149 - val_loss: 0.3857 - val_accuracy: 0.8939 - lr: 3.1250e-04 - 659ms/epoch - 3ms/step
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0003124999930150807.
# Epoch 58/100
# 240/240 - 1s - loss: 0.3142 - accuracy: 0.9147 - val_loss: 0.3859 - val_accuracy: 0.8935 - lr: 3.1250e-04 - 563ms/epoch - 2ms/step
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0003124999930150807.
# Epoch 59/100
# 240/240 - 1s - loss: 0.3141 - accuracy: 0.9149 - val_loss: 0.3852 - val_accuracy: 0.8933 - lr: 3.1250e-04 - 530ms/epoch - 2ms/step
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0003124999930150807.
# Epoch 60/100
# 240/240 - 1s - loss: 0.3142 - accuracy: 0.9151 - val_loss: 0.3861 - val_accuracy: 0.8940 - lr: 3.1250e-04 - 580ms/epoch - 2ms/step
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.00015624999650754035.
# Epoch 61/100
# 240/240 - 1s - loss: 0.3136 - accuracy: 0.9146 - val_loss: 0.3858 - val_accuracy: 0.8941 - lr: 1.5625e-04 - 532ms/epoch - 2ms/step
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.00015624999650754035.
# Epoch 62/100
# 240/240 - 1s - loss: 0.3136 - accuracy: 0.9153 - val_loss: 0.3855 - val_accuracy: 0.8934 - lr: 1.5625e-04 - 538ms/epoch - 2ms/step
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.00015624999650754035.
# Epoch 63/100
# 240/240 - 1s - loss: 0.3135 - accuracy: 0.9152 - val_loss: 0.3858 - val_accuracy: 0.8943 - lr: 1.5625e-04 - 539ms/epoch - 2ms/step
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.00015624999650754035.
# Epoch 64/100
# 240/240 - 1s - loss: 0.3135 - accuracy: 0.9149 - val_loss: 0.3856 - val_accuracy: 0.8943 - lr: 1.5625e-04 - 551ms/epoch - 2ms/step
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.00015624999650754035.
# Epoch 65/100
# 240/240 - 1s - loss: 0.3135 - accuracy: 0.9154 - val_loss: 0.3862 - val_accuracy: 0.8937 - lr: 1.5625e-04 - 548ms/epoch - 2ms/step
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.00015624999650754035.
# Epoch 66/100
# 240/240 - 1s - loss: 0.3134 - accuracy: 0.9151 - val_loss: 0.3857 - val_accuracy: 0.8941 - lr: 1.5625e-04 - 544ms/epoch - 2ms/step
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.00015624999650754035.
# Epoch 67/100
# 240/240 - 1s - loss: 0.3135 - accuracy: 0.9151 - val_loss: 0.3858 - val_accuracy: 0.8942 - lr: 1.5625e-04 - 563ms/epoch - 2ms/step
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.00015624999650754035.
# Epoch 68/100
# 240/240 - 1s - loss: 0.3135 - accuracy: 0.9151 - val_loss: 0.3856 - val_accuracy: 0.8938 - lr: 1.5625e-04 - 536ms/epoch - 2ms/step
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.00015624999650754035.
# Epoch 69/100
# 240/240 - 1s - loss: 0.3134 - accuracy: 0.9152 - val_loss: 0.3853 - val_accuracy: 0.8938 - lr: 1.5625e-04 - 526ms/epoch - 2ms/step
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.00015624999650754035.
# Epoch 70/100
# 240/240 - 1s - loss: 0.3134 - accuracy: 0.9156 - val_loss: 0.3855 - val_accuracy: 0.8934 - lr: 1.5625e-04 - 558ms/epoch - 2ms/step
#
# Epoch 71: LearningRateScheduler setting learning rate to 7.812499825377017e-05.
# Epoch 71/100
# 240/240 - 1s - loss: 0.3131 - accuracy: 0.9156 - val_loss: 0.3854 - val_accuracy: 0.8942 - lr: 7.8125e-05 - 610ms/epoch - 3ms/step
#
# Epoch 72: LearningRateScheduler setting learning rate to 7.812499825377017e-05.
# Epoch 72/100
# 240/240 - 1s - loss: 0.3131 - accuracy: 0.9154 - val_loss: 0.3858 - val_accuracy: 0.8938 - lr: 7.8125e-05 - 688ms/epoch - 3ms/step
#
# Epoch 73: LearningRateScheduler setting learning rate to 7.812499825377017e-05.
# Epoch 73/100
# 240/240 - 1s - loss: 0.3131 - accuracy: 0.9156 - val_loss: 0.3857 - val_accuracy: 0.8941 - lr: 7.8125e-05 - 630ms/epoch - 3ms/step
#
# Epoch 74: LearningRateScheduler setting learning rate to 7.812499825377017e-05.
# Epoch 74/100
# 240/240 - 1s - loss: 0.3130 - accuracy: 0.9152 - val_loss: 0.3856 - val_accuracy: 0.8935 - lr: 7.8125e-05 - 629ms/epoch - 3ms/step
#
# Epoch 75: LearningRateScheduler setting learning rate to 7.812499825377017e-05.
# Epoch 75/100
# 240/240 - 1s - loss: 0.3130 - accuracy: 0.9156 - val_loss: 0.3857 - val_accuracy: 0.8938 - lr: 7.8125e-05 - 569ms/epoch - 2ms/step
#
# Epoch 76: LearningRateScheduler setting learning rate to 7.812499825377017e-05.
# Epoch 76/100
# 240/240 - 1s - loss: 0.3130 - accuracy: 0.9155 - val_loss: 0.3855 - val_accuracy: 0.8936 - lr: 7.8125e-05 - 652ms/epoch - 3ms/step
#
# Epoch 77: LearningRateScheduler setting learning rate to 7.812499825377017e-05.
# Epoch 77/100
# 240/240 - 1s - loss: 0.3131 - accuracy: 0.9152 - val_loss: 0.3855 - val_accuracy: 0.8936 - lr: 7.8125e-05 - 573ms/epoch - 2ms/step
#
# Epoch 78: LearningRateScheduler setting learning rate to 7.812499825377017e-05.
# Epoch 78/100
# 240/240 - 1s - loss: 0.3130 - accuracy: 0.9155 - val_loss: 0.3854 - val_accuracy: 0.8943 - lr: 7.8125e-05 - 537ms/epoch - 2ms/step
#
# Epoch 79: LearningRateScheduler setting learning rate to 7.812499825377017e-05.
# Epoch 79/100
# 240/240 - 1s - loss: 0.3130 - accuracy: 0.9154 - val_loss: 0.3857 - val_accuracy: 0.8938 - lr: 7.8125e-05 - 521ms/epoch - 2ms/step
#
# Epoch 80: LearningRateScheduler setting learning rate to 7.812499825377017e-05.
# Epoch 80/100
# 240/240 - 1s - loss: 0.3130 - accuracy: 0.9153 - val_loss: 0.3855 - val_accuracy: 0.8942 - lr: 7.8125e-05 - 519ms/epoch - 2ms/step
#
# Epoch 81: LearningRateScheduler setting learning rate to 3.9062499126885086e-05.
# Epoch 81/100
# 240/240 - 1s - loss: 0.3128 - accuracy: 0.9155 - val_loss: 0.3856 - val_accuracy: 0.8943 - lr: 3.9062e-05 - 535ms/epoch - 2ms/step
#
# Epoch 82: LearningRateScheduler setting learning rate to 3.9062499126885086e-05.
# Epoch 82/100
# 240/240 - 1s - loss: 0.3128 - accuracy: 0.9154 - val_loss: 0.3857 - val_accuracy: 0.8941 - lr: 3.9062e-05 - 623ms/epoch - 3ms/step
#
# Epoch 83: LearningRateScheduler setting learning rate to 3.9062499126885086e-05.
# Epoch 83/100
# 240/240 - 1s - loss: 0.3128 - accuracy: 0.9154 - val_loss: 0.3856 - val_accuracy: 0.8943 - lr: 3.9062e-05 - 715ms/epoch - 3ms/step
#
# Epoch 84: LearningRateScheduler setting learning rate to 3.9062499126885086e-05.
# Epoch 84/100
# 240/240 - 1s - loss: 0.3128 - accuracy: 0.9156 - val_loss: 0.3857 - val_accuracy: 0.8942 - lr: 3.9062e-05 - 769ms/epoch - 3ms/step
#
# Epoch 85: LearningRateScheduler setting learning rate to 3.9062499126885086e-05.
# Epoch 85/100
# 240/240 - 1s - loss: 0.3128 - accuracy: 0.9154 - val_loss: 0.3856 - val_accuracy: 0.8941 - lr: 3.9062e-05 - 822ms/epoch - 3ms/step
#
# Epoch 86: LearningRateScheduler setting learning rate to 3.9062499126885086e-05.
# Epoch 86/100
# 240/240 - 1s - loss: 0.3128 - accuracy: 0.9155 - val_loss: 0.3855 - val_accuracy: 0.8940 - lr: 3.9062e-05 - 690ms/epoch - 3ms/step
#
# Epoch 87: LearningRateScheduler setting learning rate to 3.9062499126885086e-05.
# Epoch 87/100
# 240/240 - 1s - loss: 0.3128 - accuracy: 0.9156 - val_loss: 0.3856 - val_accuracy: 0.8939 - lr: 3.9062e-05 - 656ms/epoch - 3ms/step
#
# Epoch 88: LearningRateScheduler setting learning rate to 3.9062499126885086e-05.
# Epoch 88/100
# 240/240 - 1s - loss: 0.3128 - accuracy: 0.9156 - val_loss: 0.3856 - val_accuracy: 0.8937 - lr: 3.9062e-05 - 642ms/epoch - 3ms/step
#
# Epoch 89: LearningRateScheduler setting learning rate to 3.9062499126885086e-05.
# Epoch 89/100
# 240/240 - 1s - loss: 0.3128 - accuracy: 0.9154 - val_loss: 0.3856 - val_accuracy: 0.8935 - lr: 3.9062e-05 - 962ms/epoch - 4ms/step
#
# Epoch 90: LearningRateScheduler setting learning rate to 3.9062499126885086e-05.
# Epoch 90/100
# 240/240 - 1s - loss: 0.3128 - accuracy: 0.9155 - val_loss: 0.3857 - val_accuracy: 0.8941 - lr: 3.9062e-05 - 626ms/epoch - 3ms/step
#
# Epoch 91: LearningRateScheduler setting learning rate to 1.9531249563442543e-05.
# Epoch 91/100
# 240/240 - 1s - loss: 0.3127 - accuracy: 0.9154 - val_loss: 0.3856 - val_accuracy: 0.8942 - lr: 1.9531e-05 - 593ms/epoch - 2ms/step
#
# Epoch 92: LearningRateScheduler setting learning rate to 1.9531249563442543e-05.
# Epoch 92/100
# 240/240 - 1s - loss: 0.3127 - accuracy: 0.9155 - val_loss: 0.3856 - val_accuracy: 0.8939 - lr: 1.9531e-05 - 664ms/epoch - 3ms/step
#
# Epoch 93: LearningRateScheduler setting learning rate to 1.9531249563442543e-05.
# Epoch 93/100
# 240/240 - 1s - loss: 0.3127 - accuracy: 0.9155 - val_loss: 0.3856 - val_accuracy: 0.8942 - lr: 1.9531e-05 - 727ms/epoch - 3ms/step
#
# Epoch 94: LearningRateScheduler setting learning rate to 1.9531249563442543e-05.
# Epoch 94/100
# 240/240 - 1s - loss: 0.3127 - accuracy: 0.9156 - val_loss: 0.3856 - val_accuracy: 0.8940 - lr: 1.9531e-05 - 705ms/epoch - 3ms/step
#
# Epoch 95: LearningRateScheduler setting learning rate to 1.9531249563442543e-05.
# Epoch 95/100
# 240/240 - 1s - loss: 0.3127 - accuracy: 0.9155 - val_loss: 0.3856 - val_accuracy: 0.8940 - lr: 1.9531e-05 - 836ms/epoch - 3ms/step
#
# Epoch 96: LearningRateScheduler setting learning rate to 1.9531249563442543e-05.
# Epoch 96/100
# 240/240 - 1s - loss: 0.3127 - accuracy: 0.9156 - val_loss: 0.3856 - val_accuracy: 0.8941 - lr: 1.9531e-05 - 609ms/epoch - 3ms/step
#
# Epoch 97: LearningRateScheduler setting learning rate to 1.9531249563442543e-05.
# Epoch 97/100
# 240/240 - 1s - loss: 0.3127 - accuracy: 0.9154 - val_loss: 0.3856 - val_accuracy: 0.8941 - lr: 1.9531e-05 - 864ms/epoch - 4ms/step
#
# Epoch 98: LearningRateScheduler setting learning rate to 1.9531249563442543e-05.
# Epoch 98/100
# 240/240 - 1s - loss: 0.3127 - accuracy: 0.9155 - val_loss: 0.3856 - val_accuracy: 0.8942 - lr: 1.9531e-05 - 634ms/epoch - 3ms/step
#
# Epoch 99: LearningRateScheduler setting learning rate to 1.9531249563442543e-05.
# Epoch 99/100
# 240/240 - 1s - loss: 0.3127 - accuracy: 0.9155 - val_loss: 0.3856 - val_accuracy: 0.8942 - lr: 1.9531e-05 - 632ms/epoch - 3ms/step
#
# Epoch 100: LearningRateScheduler setting learning rate to 1.9531249563442543e-05.
# Epoch 100/100
# 240/240 - 1s - loss: 0.3127 - accuracy: 0.9155 - val_loss: 0.3856 - val_accuracy: 0.8942 - lr: 1.9531e-05 - 835ms/epoch - 3ms/step

# %%
! tensorboard --logdir C:/Users/nonel/tmp/log/3101
# Out:
# 'tensorboard'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
import os
path = "C:/Users/nonel/tmp/log/"
if not os.path.isdir(path):
    os.mkdir(path)
##logdir = path + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") 
logdir = path + "3101"
##callback = tf.keras.callbacks. TensorBoard (log_dir=logdir)
callback = tf.keras.callbacks. TensorBoard (log_dir=logdir, update_freq='epoch', histogram_freq= 10, write_images=True)
#6
ret = model.fit(x_train, y_train, epochs=20, batch_size=200,
                validation_split =0.2, verbose=2, callbacks=[callback])
# Out:
# Epoch 1/20
# 240/240 - 1s - loss: 1.1355 - accuracy: 0.7225 - val_loss: 0.6769 - val_accuracy: 0.8332 - 1s/epoch - 5ms/step
# Epoch 2/20
# 240/240 - 0s - loss: 0.6210 - accuracy: 0.8336 - val_loss: 0.5503 - val_accuracy: 0.8466 - 498ms/epoch - 2ms/step
# Epoch 3/20
# 240/240 - 0s - loss: 0.5457 - accuracy: 0.8484 - val_loss: 0.5139 - val_accuracy: 0.8570 - 484ms/epoch - 2ms/step
# Epoch 4/20
# 240/240 - 0s - loss: 0.5188 - accuracy: 0.8554 - val_loss: 0.4945 - val_accuracy: 0.8624 - 481ms/epoch - 2ms/step
# Epoch 5/20
# 240/240 - 0s - loss: 0.5046 - accuracy: 0.8578 - val_loss: 0.5096 - val_accuracy: 0.8547 - 385ms/epoch - 2ms/step
# Epoch 6/20
# 240/240 - 0s - loss: 0.4934 - accuracy: 0.8624 - val_loss: 0.4735 - val_accuracy: 0.8676 - 371ms/epoch - 2ms/step
# Epoch 7/20
# 240/240 - 0s - loss: 0.4884 - accuracy: 0.8620 - val_loss: 0.4994 - val_accuracy: 0.8547 - 402ms/epoch - 2ms/step
# Epoch 8/20
# 240/240 - 0s - loss: 0.4817 - accuracy: 0.8651 - val_loss: 0.4720 - val_accuracy: 0.8652 - 381ms/epoch - 2ms/step
# Epoch 9/20
# 240/240 - 0s - loss: 0.4788 - accuracy: 0.8656 - val_loss: 0.4641 - val_accuracy: 0.8668 - 401ms/epoch - 2ms/step
# Epoch 10/20
# 240/240 - 0s - loss: 0.4738 - accuracy: 0.8664 - val_loss: 0.4781 - val_accuracy: 0.8631 - 383ms/epoch - 2ms/step
# Epoch 11/20
# 240/240 - 0s - loss: 0.4707 - accuracy: 0.8679 - val_loss: 0.4633 - val_accuracy: 0.8681 - 447ms/epoch - 2ms/step
# Epoch 12/20
# 240/240 - 0s - loss: 0.4675 - accuracy: 0.8698 - val_loss: 0.4624 - val_accuracy: 0.8671 - 406ms/epoch - 2ms/step
# Epoch 13/20
# 240/240 - 0s - loss: 0.4666 - accuracy: 0.8678 - val_loss: 0.4560 - val_accuracy: 0.8692 - 415ms/epoch - 2ms/step
# Epoch 14/20
# 240/240 - 0s - loss: 0.4657 - accuracy: 0.8684 - val_loss: 0.5010 - val_accuracy: 0.8550 - 434ms/epoch - 2ms/step
# Epoch 15/20
# 240/240 - 0s - loss: 0.4629 - accuracy: 0.8690 - val_loss: 0.4666 - val_accuracy: 0.8666 - 422ms/epoch - 2ms/step
# Epoch 16/20
# 240/240 - 0s - loss: 0.4622 - accuracy: 0.8699 - val_loss: 0.4801 - val_accuracy: 0.8591 - 448ms/epoch - 2ms/step
# Epoch 17/20
# 240/240 - 0s - loss: 0.4595 - accuracy: 0.8708 - val_loss: 0.4575 - val_accuracy: 0.8680 - 400ms/epoch - 2ms/step
# Epoch 18/20
# 240/240 - 0s - loss: 0.4565 - accuracy: 0.8719 - val_loss: 0.4514 - val_accuracy: 0.8704 - 420ms/epoch - 2ms/step
# Epoch 19/20
# 240/240 - 0s - loss: 0.4572 - accuracy: 0.8710 - val_loss: 0.4552 - val_accuracy: 0.8718 - 419ms/epoch - 2ms/step
# Epoch 20/20
# 240/240 - 1s - loss: 0.4571 - accuracy: 0.8704 - val_loss: 0.4511 - val_accuracy: 0.8728 - 528ms/epoch - 2ms/step

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist 
import numpy as np
import matplotlib.pyplot as plt 
import datetime
#1
(x_train, y_train), (x_test, y_test) = mnist.load_data()
#2: normalize images
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.0 # [0, 1]
x_test / 255.0

#3: one-hot encoding
y_train = tf.keras.utils.to_categorical (y_train) # (60000, 10) 
y_test = tf.keras.utils.to_categorical (y_test) # (10000, 10)

#4: build a model
#4-1
# init = tf.keras.initializers.he_normal() # 'he_normal'
# act = tf.keras.activations.relu

#4-2
# 'relu'
init = tf.keras.initializers.he_normal() 
act = tf.keras.layers.LeakyReLU(alpha=0.3)

#4-3
# init = tf.keras.initializers.he_uniform() # 'he_uniform'
# act = tf.keras.layers.LeakyReLU(alpha=0.3)

# %%
n = 100
model = tf.keras.Sequential()
model.add(tf.keras.layers. Flatten (input_shape=(28, 28)))
model.add(tf.keras.layers. Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers.Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers. Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers. Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers. Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers. Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers. Dense (units=10, activation='softmax', kernel_initializer=init))
model.summary()
opt = tf.keras.optimizers.RMSprop (learning_rate=0.01)
model.compile(optimizer=opt, loss = 'categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 100)               10100
#
#  dense_4 (Dense)             (None, 100)               10100
#
#  dense_5 (Dense)             (None, 100)               10100
#
#  dense_6 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 130010 (507.85 KB)
# Trainable params: 130010 (507.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# c:\Users\nonel\anaconda3\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(

# %%
opt = tf.keras.optimizers.RMSprop(learning_rate=0.01) # ← Setting model optimizer as RMSprop 
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# #5
# callback = tf.keras.callbacks. EarlyStopping (monitor= 'val_loss', 
#                                               min_delta = 0.001, #최소 갱신 값 
#                                               patience=10, #위반 허용 횟수
#                                               verbose=1, # Callback 메시지 출력
#                                               mode = 'auto') # 'min', 'max', 'auto'

# #6
# # 
# ret = model.fit(x_train, y_train, epochs=100, batch_size=200,
#                 validation_split =0.2, verbose=2, callbacks = [callback])

# %%
#5: creates a summary file writer for the given log directory 
import os
path = "C:/Users/nonel/tmp/log/"
if not os.path.isdir(path):
    os.mkdir(path)
##logdir = path + datetime.datetime.now().strftime("%Y%m%d-%H%%S") 
logdir = path + "3203"
file_writer = tf.summary.create_file_writer (logdir + "/gradient") 
file_writer.set_as_default()

# %%
#6: calculate averages and histograms of gradients in layers 
class GradientCallback(tf.keras.callbacks.Callback):
##
##
    def __init__(self, freq=10):
        # super(GradientCallback, self).__init__() 
        self.freq = freq

    def on_epoch_end (self, epoch, logs):
        if epoch%self.freq != 0: 
            return
        with tf.GradientTape() as tape:
            y_pred = model (x_train) # tensor, logits
            loss = tf.keras. losses.binary_crossentropy(y_train, y_pred) 
        grads = tape.gradient(loss, model.trainable_weights)

        for n in range(1, len (model.layers)):
            i2 = (n-1)*2    # weights
            i1 = 12 + 1     # biases
            bias_avg = tf.reduce_mean(tf.abs(grads[i1])) 
            weight_avg = tf.reduce_mean(tf.abs(grads[12]))
            tf.summary.scalar ("layer_%d/avg/bias "%n, data=bias_avg, step=epoch) 
            tf.summary.scalar ("layer_%d/avg/weight" %n, data=weight_avg, step=epoch)
            tf.summary.histogram ("layer_%d/hist/bias" %n, data=grads [i1], step=epoch) 
            tf.summary.histogram ("layer_%d/hist/weight"%n, data=grads [12], step=epoch)

    def on_train_end(self, logs):
        tf.summary.flush()

# %%
callback1 = GradientCallback() # freq = 10
callback2 = tf.keras.callbacks.TensorBoard (log_dir=logdir, histogram_freq= 10) #profile_batch=0

#7: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2, 
                verbose=2, callbacks = [callback1, callback2])

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2) 
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
# Out:
# Epoch 1/101
# 240/240 - 4s - loss: 5.1989 - accuracy: 0.5918 - val_loss: 0.5597 - val_accuracy: 0.8407 - 4s/epoch - 17ms/step
# Epoch 2/101
# 240/240 - 1s - loss: 2.0090 - accuracy: 0.7329 - val_loss: 1.6764 - val_accuracy: 0.5258 - 1s/epoch - 6ms/step
# Epoch 3/101
# 240/240 - 1s - loss: 1.3189 - accuracy: 0.7813 - val_loss: 0.2928 - val_accuracy: 0.9212 - 1s/epoch - 6ms/step
# Epoch 4/101
# 240/240 - 1s - loss: 0.6130 - accuracy: 0.8438 - val_loss: 0.8656 - val_accuracy: 0.8319 - 1s/epoch - 5ms/step
# Epoch 5/101
# 240/240 - 1s - loss: 0.4225 - accuracy: 0.8902 - val_loss: 0.2232 - val_accuracy: 0.9417 - 1s/epoch - 5ms/step
# Epoch 6/101
# 240/240 - 1s - loss: 0.4114 - accuracy: 0.8988 - val_loss: 0.2173 - val_accuracy: 0.9423 - 1s/epoch - 6ms/step
# Epoch 7/101
# 240/240 - 1s - loss: 0.3177 - accuracy: 0.9170 - val_loss: 0.2587 - val_accuracy: 0.9346 - 1s/epoch - 6ms/step
# Epoch 8/101
# 240/240 - 1s - loss: 0.2714 - accuracy: 0.9292 - val_loss: 0.3577 - val_accuracy: 0.9026 - 1s/epoch - 6ms/step
# Epoch 9/101
# 240/240 - 1s - loss: 0.2428 - accuracy: 0.9371 - val_loss: 0.1753 - val_accuracy: 0.9548 - 1s/epoch - 6ms/step
# Epoch 10/101
# 240/240 - 1s - loss: 0.2774 - accuracy: 0.9351 - val_loss: 0.1728 - val_accuracy: 0.9557 - 1s/epoch - 5ms/step
# Epoch 11/101
# 240/240 - 2s - loss: 0.2473 - accuracy: 0.9407 - val_loss: 0.2295 - val_accuracy: 0.9417 - 2s/epoch - 10ms/step
# Epoch 12/101
# 240/240 - 1s - loss: 0.2158 - accuracy: 0.9443 - val_loss: 0.2825 - val_accuracy: 0.9367 - 1s/epoch - 6ms/step
# Epoch 13/101
# 240/240 - 2s - loss: 0.2014 - accuracy: 0.9487 - val_loss: 0.1682 - val_accuracy: 0.9568 - 2s/epoch - 6ms/step
# Epoch 14/101
# 240/240 - 1s - loss: 0.2407 - accuracy: 0.9463 - val_loss: 0.1596 - val_accuracy: 0.9602 - 1s/epoch - 6ms/step
# Epoch 15/101
# 240/240 - 2s - loss: 0.2246 - accuracy: 0.9485 - val_loss: 0.2465 - val_accuracy: 0.9434 - 2s/epoch - 6ms/step
# Epoch 16/101
# 240/240 - 1s - loss: 0.2894 - accuracy: 0.9449 - val_loss: 0.1478 - val_accuracy: 0.9645 - 1s/epoch - 6ms/step
# Epoch 17/101
# 240/240 - 2s - loss: 0.2482 - accuracy: 0.9492 - val_loss: 0.1698 - val_accuracy: 0.9599 - 2s/epoch - 7ms/step
# Epoch 18/101
# 240/240 - 1s - loss: 0.2039 - accuracy: 0.9520 - val_loss: 0.2079 - val_accuracy: 0.9584 - 1s/epoch - 6ms/step
# Epoch 19/101
# 240/240 - 1s - loss: 0.2241 - accuracy: 0.9526 - val_loss: 0.1950 - val_accuracy: 0.9571 - 1s/epoch - 6ms/step
# Epoch 20/101
# 240/240 - 1s - loss: 0.2430 - accuracy: 0.9516 - val_loss: 0.1530 - val_accuracy: 0.9632 - 1s/epoch - 6ms/step
# Epoch 21/101
# 240/240 - 2s - loss: 0.1911 - accuracy: 0.9570 - val_loss: 0.2326 - val_accuracy: 0.9499 - 2s/epoch - 10ms/step
# Epoch 22/101
# 240/240 - 1s - loss: 0.2169 - accuracy: 0.9550 - val_loss: 0.1596 - val_accuracy: 0.9616 - 1s/epoch - 6ms/step
# Epoch 23/101
# 240/240 - 1s - loss: 0.2098 - accuracy: 0.9542 - val_loss: 0.1614 - val_accuracy: 0.9664 - 1s/epoch - 6ms/step
# Epoch 24/101
# 240/240 - 1s - loss: 0.2137 - accuracy: 0.9554 - val_loss: 0.1741 - val_accuracy: 0.9611 - 1s/epoch - 5ms/step
# Epoch 25/101
# 240/240 - 1s - loss: 0.2246 - accuracy: 0.9564 - val_loss: 0.5528 - val_accuracy: 0.8775 - 1s/epoch - 5ms/step
# Epoch 26/101
# 240/240 - 1s - loss: 0.1974 - accuracy: 0.9583 - val_loss: 0.9952 - val_accuracy: 0.7798 - 1s/epoch - 6ms/step
# Epoch 27/101
# 240/240 - 1s - loss: 0.1817 - accuracy: 0.9594 - val_loss: 0.3306 - val_accuracy: 0.9341 - 1s/epoch - 6ms/step
# Epoch 28/101
# 240/240 - 1s - loss: 0.2493 - accuracy: 0.9551 - val_loss: 0.1602 - val_accuracy: 0.9653 - 1s/epoch - 6ms/step
# Epoch 29/101
# 240/240 - 1s - loss: 0.1699 - accuracy: 0.9614 - val_loss: 0.1981 - val_accuracy: 0.9542 - 1s/epoch - 6ms/step
# Epoch 30/101
# 240/240 - 1s - loss: 0.2176 - accuracy: 0.9581 - val_loss: 0.2134 - val_accuracy: 0.9521 - 1s/epoch - 6ms/step
# Epoch 31/101
# 240/240 - 2s - loss: 0.1785 - accuracy: 0.9607 - val_loss: 0.2333 - val_accuracy: 0.9590 - 2s/epoch - 10ms/step
# Epoch 32/101
# 240/240 - 2s - loss: 0.2146 - accuracy: 0.9556 - val_loss: 0.1615 - val_accuracy: 0.9603 - 2s/epoch - 6ms/step
# Epoch 33/101
# 240/240 - 2s - loss: 0.1882 - accuracy: 0.9600 - val_loss: 0.5983 - val_accuracy: 0.8996 - 2s/epoch - 8ms/step
# Epoch 34/101
# 240/240 - 2s - loss: 0.2111 - accuracy: 0.9607 - val_loss: 0.2825 - val_accuracy: 0.9563 - 2s/epoch - 7ms/step
# Epoch 35/101
# 240/240 - 2s - loss: 0.2661 - accuracy: 0.9569 - val_loss: 0.2284 - val_accuracy: 0.9566 - 2s/epoch - 6ms/step
# Epoch 36/101
# 240/240 - 1s - loss: 0.2314 - accuracy: 0.9578 - val_loss: 0.3136 - val_accuracy: 0.9109 - 1s/epoch - 6ms/step
# Epoch 37/101
# 240/240 - 1s - loss: 0.2273 - accuracy: 0.9561 - val_loss: 0.1819 - val_accuracy: 0.9636 - 1s/epoch - 6ms/step
# Epoch 38/101
# 240/240 - 1s - loss: 0.2195 - accuracy: 0.9592 - val_loss: 0.3522 - val_accuracy: 0.9469 - 1s/epoch - 6ms/step
# Epoch 39/101
# 240/240 - 1s - loss: 0.2213 - accuracy: 0.9602 - val_loss: 0.2283 - val_accuracy: 0.9588 - 1s/epoch - 5ms/step
# Epoch 40/101
# 240/240 - 1s - loss: 0.1802 - accuracy: 0.9613 - val_loss: 0.2722 - val_accuracy: 0.9479 - 1s/epoch - 6ms/step
# Epoch 41/101
# 240/240 - 3s - loss: 0.2014 - accuracy: 0.9637 - val_loss: 1.3116 - val_accuracy: 0.8547 - 3s/epoch - 11ms/step
# Epoch 42/101
# 240/240 - 1s - loss: 0.1681 - accuracy: 0.9659 - val_loss: 0.2502 - val_accuracy: 0.9492 - 1s/epoch - 6ms/step
# Epoch 43/101
# 240/240 - 1s - loss: 0.2550 - accuracy: 0.9627 - val_loss: 0.4988 - val_accuracy: 0.8876 - 1s/epoch - 6ms/step
# Epoch 44/101
# 240/240 - 1s - loss: 0.2803 - accuracy: 0.9591 - val_loss: 0.1905 - val_accuracy: 0.9665 - 1s/epoch - 6ms/step
# Epoch 45/101
# 240/240 - 2s - loss: 0.1891 - accuracy: 0.9640 - val_loss: 0.3119 - val_accuracy: 0.9438 - 2s/epoch - 6ms/step
# Epoch 46/101
# 240/240 - 1s - loss: 0.2493 - accuracy: 0.9592 - val_loss: 0.1676 - val_accuracy: 0.9683 - 1s/epoch - 6ms/step
# Epoch 47/101
# 240/240 - 1s - loss: 0.1611 - accuracy: 0.9643 - val_loss: 0.3277 - val_accuracy: 0.9396 - 1s/epoch - 6ms/step
# Epoch 48/101
# 240/240 - 1s - loss: 0.1820 - accuracy: 0.9655 - val_loss: 0.2489 - val_accuracy: 0.9611 - 1s/epoch - 6ms/step
# Epoch 49/101
# 240/240 - 1s - loss: 0.1947 - accuracy: 0.9637 - val_loss: 0.2516 - val_accuracy: 0.9553 - 1s/epoch - 6ms/step
# Epoch 50/101
# 240/240 - 1s - loss: 0.2241 - accuracy: 0.9630 - val_loss: 0.2159 - val_accuracy: 0.9584 - 1s/epoch - 6ms/step
# Epoch 51/101
# 240/240 - 2s - loss: 0.3471 - accuracy: 0.9611 - val_loss: 0.2092 - val_accuracy: 0.9628 - 2s/epoch - 10ms/step
# Epoch 52/101
# 240/240 - 1s - loss: 0.2217 - accuracy: 0.9646 - val_loss: 0.2025 - val_accuracy: 0.9657 - 1s/epoch - 6ms/step
# Epoch 53/101
# 240/240 - 1s - loss: 0.2373 - accuracy: 0.9634 - val_loss: 0.2788 - val_accuracy: 0.9593 - 1s/epoch - 6ms/step
# Epoch 54/101
# 240/240 - 2s - loss: 0.2345 - accuracy: 0.9656 - val_loss: 0.2762 - val_accuracy: 0.9542 - 2s/epoch - 6ms/step
# Epoch 55/101
# 240/240 - 2s - loss: 0.1920 - accuracy: 0.9668 - val_loss: 0.1996 - val_accuracy: 0.9638 - 2s/epoch - 6ms/step
# Epoch 56/101
# 240/240 - 2s - loss: 0.1968 - accuracy: 0.9664 - val_loss: 0.2765 - val_accuracy: 0.9571 - 2s/epoch - 7ms/step
# Epoch 57/101
# 240/240 - 2s - loss: 0.2130 - accuracy: 0.9638 - val_loss: 0.2430 - val_accuracy: 0.9639 - 2s/epoch - 7ms/step
# Epoch 58/101
# 240/240 - 2s - loss: 0.3775 - accuracy: 0.9598 - val_loss: 0.2573 - val_accuracy: 0.9515 - 2s/epoch - 7ms/step
# Epoch 59/101
# 240/240 - 1s - loss: 0.2182 - accuracy: 0.9658 - val_loss: 0.3679 - val_accuracy: 0.9451 - 1s/epoch - 6ms/step
# Epoch 60/101
# 240/240 - 1s - loss: 0.1664 - accuracy: 0.9669 - val_loss: 0.2565 - val_accuracy: 0.9553 - 1s/epoch - 6ms/step
# Epoch 61/101
# 240/240 - 3s - loss: 0.2094 - accuracy: 0.9663 - val_loss: 0.3329 - val_accuracy: 0.9438 - 3s/epoch - 13ms/step
# Epoch 62/101
# 240/240 - 2s - loss: 0.2186 - accuracy: 0.9660 - val_loss: 0.9017 - val_accuracy: 0.8996 - 2s/epoch - 7ms/step
# Epoch 63/101
# 240/240 - 2s - loss: 0.2585 - accuracy: 0.9642 - val_loss: 0.2551 - val_accuracy: 0.9608 - 2s/epoch - 7ms/step
# Epoch 64/101
# 240/240 - 2s - loss: 0.2522 - accuracy: 0.9647 - val_loss: 0.3494 - val_accuracy: 0.9477 - 2s/epoch - 7ms/step
# Epoch 65/101
# 240/240 - 1s - loss: 0.1484 - accuracy: 0.9712 - val_loss: 0.2106 - val_accuracy: 0.9668 - 1s/epoch - 6ms/step
# Epoch 66/101
# 240/240 - 1s - loss: 0.1826 - accuracy: 0.9690 - val_loss: 0.2600 - val_accuracy: 0.9554 - 1s/epoch - 6ms/step
# Epoch 67/101
# 240/240 - 1s - loss: 0.2001 - accuracy: 0.9686 - val_loss: 0.2026 - val_accuracy: 0.9641 - 1s/epoch - 6ms/step
# Epoch 68/101
# 240/240 - 1s - loss: 0.2767 - accuracy: 0.9670 - val_loss: 0.2248 - val_accuracy: 0.9641 - 1s/epoch - 6ms/step
# Epoch 69/101
# 240/240 - 1s - loss: 0.1833 - accuracy: 0.9693 - val_loss: 0.2955 - val_accuracy: 0.9615 - 1s/epoch - 5ms/step
# Epoch 70/101
# 240/240 - 1s - loss: 0.2246 - accuracy: 0.9688 - val_loss: 0.2523 - val_accuracy: 0.9571 - 1s/epoch - 5ms/step
# Epoch 71/101
# 240/240 - 2s - loss: 0.2271 - accuracy: 0.9649 - val_loss: 0.2729 - val_accuracy: 0.9666 - 2s/epoch - 9ms/step
# Epoch 72/101
# 240/240 - 1s - loss: 0.1607 - accuracy: 0.9707 - val_loss: 0.2753 - val_accuracy: 0.9598 - 1s/epoch - 6ms/step
# Epoch 73/101
# 240/240 - 1s - loss: 0.1717 - accuracy: 0.9690 - val_loss: 0.5083 - val_accuracy: 0.9271 - 1s/epoch - 6ms/step
# Epoch 74/101
# 240/240 - 1s - loss: 0.2623 - accuracy: 0.9663 - val_loss: 0.3480 - val_accuracy: 0.9563 - 1s/epoch - 6ms/step
# Epoch 75/101
# 240/240 - 1s - loss: 0.2383 - accuracy: 0.9669 - val_loss: 0.2540 - val_accuracy: 0.9622 - 1s/epoch - 6ms/step
# Epoch 76/101
# 240/240 - 1s - loss: 0.2649 - accuracy: 0.9685 - val_loss: 0.3173 - val_accuracy: 0.9605 - 1s/epoch - 6ms/step
# Epoch 77/101
# 240/240 - 1s - loss: 0.2538 - accuracy: 0.9654 - val_loss: 1.0736 - val_accuracy: 0.8470 - 1s/epoch - 6ms/step
# Epoch 78/101
# 240/240 - 1s - loss: 0.4910 - accuracy: 0.9643 - val_loss: 0.4743 - val_accuracy: 0.9536 - 1s/epoch - 6ms/step
# Epoch 79/101
# 240/240 - 1s - loss: 0.2075 - accuracy: 0.9685 - val_loss: 0.3609 - val_accuracy: 0.9553 - 1s/epoch - 6ms/step
# Epoch 80/101
# 240/240 - 1s - loss: 0.2342 - accuracy: 0.9695 - val_loss: 0.2307 - val_accuracy: 0.9653 - 1s/epoch - 6ms/step
# Epoch 81/101
# 240/240 - 2s - loss: 0.2903 - accuracy: 0.9660 - val_loss: 0.2585 - val_accuracy: 0.9644 - 2s/epoch - 10ms/step
# Epoch 82/101
# 240/240 - 1s - loss: 0.2098 - accuracy: 0.9697 - val_loss: 0.8330 - val_accuracy: 0.9030 - 1s/epoch - 6ms/step
# Epoch 83/101
# 240/240 - 1s - loss: 0.1892 - accuracy: 0.9697 - val_loss: 0.2372 - val_accuracy: 0.9673 - 1s/epoch - 6ms/step
# Epoch 84/101
# 240/240 - 1s - loss: 0.2491 - accuracy: 0.9692 - val_loss: 1.7884 - val_accuracy: 0.8138 - 1s/epoch - 6ms/step
# Epoch 85/101
# 240/240 - 1s - loss: 0.2148 - accuracy: 0.9688 - val_loss: 0.2965 - val_accuracy: 0.9630 - 1s/epoch - 6ms/step
# Epoch 86/101
# 240/240 - 1s - loss: 0.1547 - accuracy: 0.9722 - val_loss: 0.2243 - val_accuracy: 0.9611 - 1s/epoch - 6ms/step
# Epoch 87/101
# 240/240 - 2s - loss: 0.1987 - accuracy: 0.9703 - val_loss: 0.7712 - val_accuracy: 0.9083 - 2s/epoch - 7ms/step
# Epoch 88/101
# 240/240 - 2s - loss: 0.2370 - accuracy: 0.9700 - val_loss: 0.2736 - val_accuracy: 0.9627 - 2s/epoch - 7ms/step
# Epoch 89/101
# 240/240 - 2s - loss: 0.2419 - accuracy: 0.9686 - val_loss: 0.3193 - val_accuracy: 0.9586 - 2s/epoch - 7ms/step
# Epoch 90/101
# 240/240 - 2s - loss: 0.1790 - accuracy: 0.9715 - val_loss: 0.1987 - val_accuracy: 0.9683 - 2s/epoch - 7ms/step
# Epoch 91/101
# 240/240 - 3s - loss: 0.2513 - accuracy: 0.9689 - val_loss: 0.7005 - val_accuracy: 0.9159 - 3s/epoch - 12ms/step
# Epoch 92/101
# 240/240 - 2s - loss: 0.2817 - accuracy: 0.9706 - val_loss: 0.3454 - val_accuracy: 0.9572 - 2s/epoch - 7ms/step
# Epoch 93/101
# 240/240 - 2s - loss: 0.2941 - accuracy: 0.9677 - val_loss: 0.3917 - val_accuracy: 0.9548 - 2s/epoch - 7ms/step
# Epoch 94/101
# 240/240 - 2s - loss: 0.2115 - accuracy: 0.9694 - val_loss: 0.2729 - val_accuracy: 0.9595 - 2s/epoch - 8ms/step
# Epoch 95/101
# 240/240 - 2s - loss: 0.1951 - accuracy: 0.9701 - val_loss: 0.2592 - val_accuracy: 0.9688 - 2s/epoch - 7ms/step
# Epoch 96/101
# 240/240 - 2s - loss: 0.2169 - accuracy: 0.9723 - val_loss: 0.2773 - val_accuracy: 0.9651 - 2s/epoch - 7ms/step
# Epoch 97/101
# 240/240 - 2s - loss: 0.2251 - accuracy: 0.9703 - val_loss: 0.3076 - val_accuracy: 0.9537 - 2s/epoch - 7ms/step
# Epoch 98/101
# 240/240 - 2s - loss: 0.2966 - accuracy: 0.9689 - val_loss: 0.2806 - val_accuracy: 0.9660 - 2s/epoch - 7ms/step
# Epoch 99/101
# 240/240 - 2s - loss: 0.2167 - accuracy: 0.9717 - val_loss: 0.3043 - val_accuracy: 0.9613 - 2s/epoch - 6ms/step
# Epoch 100/101
# 240/240 - 1s - loss: 0.2870 - accuracy: 0.9678 - val_loss: 1.0437 - val_accuracy: 0.9225 - 1s/epoch - 6ms/step
# Epoch 101/101
# 240/240 - 2s - loss: 0.2355 - accuracy: 0.9725 - val_loss: 0.3245 - val_accuracy: 0.9606 - 2s/epoch - 10ms/step
# 1875/1875 - 3s - loss: 0.1198 - accuracy: 0.9786 - 3s/epoch - 2ms/step
# 313/313 - 1s - loss: 119.2597 - accuracy: 0.9579 - 552ms/epoch - 2ms/step

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist 
import numpy as np
import matplotlib.pyplot as plt 
import datetime
#1
(x_train, y_train), (x_test, y_test) = mnist.load_data()
#2: normalize images
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.0 # [0, 1]
x_test / 255.0

#3: one-hot encoding
y_train = tf.keras.utils.to_categorical (y_train) # (60000, 10) 
y_test = tf.keras.utils.to_categorical (y_test) # (10000, 10)

#4: build a model

init = tf.keras.initializers.RandomUniform(0.0, 1.0)
act = tf.keras.layers.LeakyReLU(alpha=0.3)

# %%
n = 100
model = tf.keras.Sequential()
model.add(tf.keras.layers. Flatten (input_shape=(28, 28)))
model.add(tf.keras.layers. Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers. Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers.Dense (units=n, activation=act, kernel_initializer=init))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers. Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers.Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers. BatchNormalization())
model.add(tf.keras.layers. Dense (units=n, activation=act, kernel_initializer=init)) 
model.add(tf.keras.layers. Dense (units=10, activation='softmax', kernel_initializer=init))
model.summary()
opt = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_7 (Dense)             (None, 100)               78500
#
#  dense_8 (Dense)             (None, 100)               10100
#
#  dense_9 (Dense)             (None, 100)               10100
#
#  batch_normalization_2 (Bat  (None, 100)               400
#  chNormalization)
#
#  dense_10 (Dense)            (None, 100)               10100
#
#  dense_11 (Dense)            (None, 100)               10100
#
#  batch_normalization_3 (Bat  (None, 100)               400
#  chNormalization)
#
#  dense_12 (Dense)            (None, 100)               10100
#
#  dense_13 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 130810 (510.98 KB)
# Trainable params: 130410 (509.41 KB)
# Non-trainable params: 400 (1.56 KB)
# _________________________________________________________________

# %%
callback1 = GradientCallback() # freq = 10
callback2 = tf.keras.callbacks.TensorBoard (log_dir=logdir, histogram_freq= 10) #profile_batch=0

#7: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2, 
                verbose=2, callbacks = [callback1, callback2])
# Out:
# Epoch 1/101
# 240/240 - 4s - loss: 7.9480 - accuracy: 0.1976 - val_loss: 2.1611 - val_accuracy: 0.1913 - 4s/epoch - 15ms/step
# Epoch 2/101
# 240/240 - 1s - loss: 1.9041 - accuracy: 0.2766 - val_loss: 1.7873 - val_accuracy: 0.2893 - 1s/epoch - 5ms/step
# Epoch 3/101
# 240/240 - 1s - loss: 1.7780 - accuracy: 0.2919 - val_loss: 1.7409 - val_accuracy: 0.2271 - 1s/epoch - 5ms/step
# Epoch 4/101
# 240/240 - 2s - loss: 1.7397 - accuracy: 0.2960 - val_loss: 1.6442 - val_accuracy: 0.2941 - 2s/epoch - 7ms/step
# Epoch 5/101
# 240/240 - 2s - loss: 1.7100 - accuracy: 0.3076 - val_loss: 1.6357 - val_accuracy: 0.3261 - 2s/epoch - 8ms/step
# Epoch 6/101
# 240/240 - 2s - loss: 1.6807 - accuracy: 0.3245 - val_loss: 1.6038 - val_accuracy: 0.3418 - 2s/epoch - 8ms/step
# Epoch 7/101
# 240/240 - 2s - loss: 1.6370 - accuracy: 0.3437 - val_loss: 1.5378 - val_accuracy: 0.4041 - 2s/epoch - 7ms/step
# Epoch 8/101
# 240/240 - 2s - loss: 1.5822 - accuracy: 0.3784 - val_loss: 1.5268 - val_accuracy: 0.3873 - 2s/epoch - 7ms/step
# Epoch 9/101
# 240/240 - 2s - loss: 1.5372 - accuracy: 0.3954 - val_loss: 1.6104 - val_accuracy: 0.3674 - 2s/epoch - 7ms/step
# Epoch 10/101
# 240/240 - 2s - loss: 1.4698 - accuracy: 0.4172 - val_loss: 1.3536 - val_accuracy: 0.4926 - 2s/epoch - 7ms/step
# Epoch 11/101
# 240/240 - 3s - loss: 1.4312 - accuracy: 0.4353 - val_loss: 1.3448 - val_accuracy: 0.4708 - 3s/epoch - 13ms/step
# Epoch 12/101
# 240/240 - 2s - loss: 1.3819 - accuracy: 0.4442 - val_loss: 1.5420 - val_accuracy: 0.3573 - 2s/epoch - 7ms/step
# Epoch 13/101
# 240/240 - 2s - loss: 1.3368 - accuracy: 0.4634 - val_loss: 1.2197 - val_accuracy: 0.5343 - 2s/epoch - 7ms/step
# Epoch 14/101
# 240/240 - 2s - loss: 1.2937 - accuracy: 0.4863 - val_loss: 1.3324 - val_accuracy: 0.4461 - 2s/epoch - 7ms/step
# Epoch 15/101
# 240/240 - 2s - loss: 1.2777 - accuracy: 0.4874 - val_loss: 1.7398 - val_accuracy: 0.3250 - 2s/epoch - 7ms/step
# Epoch 16/101
# 240/240 - 2s - loss: 1.2285 - accuracy: 0.5047 - val_loss: 1.4968 - val_accuracy: 0.3453 - 2s/epoch - 7ms/step
# Epoch 17/101
# 240/240 - 2s - loss: 1.2329 - accuracy: 0.5040 - val_loss: 1.1854 - val_accuracy: 0.4958 - 2s/epoch - 7ms/step
# Epoch 18/101
# 240/240 - 2s - loss: 1.1949 - accuracy: 0.5191 - val_loss: 1.2210 - val_accuracy: 0.4891 - 2s/epoch - 7ms/step
# Epoch 19/101
# 240/240 - 2s - loss: 1.1962 - accuracy: 0.5189 - val_loss: 1.0804 - val_accuracy: 0.5723 - 2s/epoch - 6ms/step
# Epoch 20/101
# 240/240 - 2s - loss: 1.1167 - accuracy: 0.5582 - val_loss: 1.1935 - val_accuracy: 0.4952 - 2s/epoch - 7ms/step
# Epoch 21/101
# 240/240 - 3s - loss: 0.8588 - accuracy: 0.6990 - val_loss: 0.7779 - val_accuracy: 0.7392 - 3s/epoch - 12ms/step
# Epoch 22/101
# 240/240 - 2s - loss: 0.7173 - accuracy: 0.7650 - val_loss: 0.7543 - val_accuracy: 0.7251 - 2s/epoch - 6ms/step
# Epoch 23/101
# 240/240 - 2s - loss: 0.6360 - accuracy: 0.7969 - val_loss: 0.5987 - val_accuracy: 0.8136 - 2s/epoch - 6ms/step
# Epoch 24/101
# 240/240 - 1s - loss: 0.5473 - accuracy: 0.8294 - val_loss: 0.5944 - val_accuracy: 0.7951 - 1s/epoch - 6ms/step
# Epoch 25/101
# 240/240 - 2s - loss: 0.4564 - accuracy: 0.8598 - val_loss: 0.7256 - val_accuracy: 0.7448 - 2s/epoch - 7ms/step
# Epoch 26/101
# 240/240 - 2s - loss: 0.3774 - accuracy: 0.8881 - val_loss: 0.4190 - val_accuracy: 0.8698 - 2s/epoch - 7ms/step
# Epoch 27/101
# 240/240 - 2s - loss: 0.3196 - accuracy: 0.9074 - val_loss: 0.4827 - val_accuracy: 0.8423 - 2s/epoch - 6ms/step
# Epoch 28/101
# 240/240 - 2s - loss: 0.2844 - accuracy: 0.9165 - val_loss: 0.3641 - val_accuracy: 0.8913 - 2s/epoch - 7ms/step
# Epoch 29/101
# 240/240 - 2s - loss: 0.2549 - accuracy: 0.9246 - val_loss: 0.2575 - val_accuracy: 0.9282 - 2s/epoch - 7ms/step
# Epoch 30/101
# 240/240 - 2s - loss: 0.2312 - accuracy: 0.9322 - val_loss: 0.3135 - val_accuracy: 0.9065 - 2s/epoch - 7ms/step
# Epoch 31/101
# 240/240 - 3s - loss: 0.2086 - accuracy: 0.9382 - val_loss: 0.3491 - val_accuracy: 0.8972 - 3s/epoch - 13ms/step
# Epoch 32/101
# 240/240 - 2s - loss: 0.1897 - accuracy: 0.9442 - val_loss: 0.5160 - val_accuracy: 0.8441 - 2s/epoch - 8ms/step
# Epoch 33/101
# 240/240 - 2s - loss: 0.1762 - accuracy: 0.9490 - val_loss: 0.2423 - val_accuracy: 0.9261 - 2s/epoch - 10ms/step
# Epoch 34/101
# 240/240 - 2s - loss: 0.1623 - accuracy: 0.9511 - val_loss: 0.3077 - val_accuracy: 0.9105 - 2s/epoch - 8ms/step
# Epoch 35/101
# 240/240 - 2s - loss: 0.1504 - accuracy: 0.9547 - val_loss: 0.1902 - val_accuracy: 0.9433 - 2s/epoch - 9ms/step
# Epoch 36/101
# 240/240 - 2s - loss: 0.1388 - accuracy: 0.9585 - val_loss: 0.1803 - val_accuracy: 0.9474 - 2s/epoch - 9ms/step
# Epoch 37/101
# 240/240 - 2s - loss: 0.1293 - accuracy: 0.9609 - val_loss: 0.2237 - val_accuracy: 0.9331 - 2s/epoch - 8ms/step
# Epoch 38/101
# 240/240 - 2s - loss: 0.1191 - accuracy: 0.9644 - val_loss: 0.6787 - val_accuracy: 0.7870 - 2s/epoch - 7ms/step
# Epoch 39/101
# 240/240 - 2s - loss: 0.1143 - accuracy: 0.9652 - val_loss: 0.5314 - val_accuracy: 0.8543 - 2s/epoch - 6ms/step
# Epoch 40/101
# 240/240 - 2s - loss: 0.1068 - accuracy: 0.9676 - val_loss: 0.1941 - val_accuracy: 0.9482 - 2s/epoch - 8ms/step
# Epoch 41/101
# 240/240 - 4s - loss: 0.1010 - accuracy: 0.9682 - val_loss: 0.3849 - val_accuracy: 0.8984 - 4s/epoch - 15ms/step
# Epoch 42/101
# 240/240 - 2s - loss: 0.0955 - accuracy: 0.9703 - val_loss: 0.2321 - val_accuracy: 0.9336 - 2s/epoch - 7ms/step
# Epoch 43/101
# 240/240 - 2s - loss: 0.0893 - accuracy: 0.9719 - val_loss: 0.1474 - val_accuracy: 0.9583 - 2s/epoch - 7ms/step
# Epoch 44/101
# 240/240 - 1s - loss: 0.0864 - accuracy: 0.9738 - val_loss: 0.2057 - val_accuracy: 0.9474 - 1s/epoch - 6ms/step
# Epoch 45/101
# 240/240 - 2s - loss: 0.0832 - accuracy: 0.9739 - val_loss: 0.2342 - val_accuracy: 0.9390 - 2s/epoch - 6ms/step
# Epoch 46/101
# 240/240 - 1s - loss: 0.0805 - accuracy: 0.9750 - val_loss: 0.1710 - val_accuracy: 0.9538 - 1s/epoch - 6ms/step
# Epoch 47/101
# 240/240 - 2s - loss: 0.0759 - accuracy: 0.9756 - val_loss: 0.1348 - val_accuracy: 0.9648 - 2s/epoch - 6ms/step
# Epoch 48/101
# 240/240 - 1s - loss: 0.0724 - accuracy: 0.9776 - val_loss: 0.1694 - val_accuracy: 0.9575 - 1s/epoch - 6ms/step
# Epoch 49/101
# 240/240 - 2s - loss: 0.0709 - accuracy: 0.9776 - val_loss: 0.1554 - val_accuracy: 0.9597 - 2s/epoch - 6ms/step
# Epoch 50/101
# 240/240 - 1s - loss: 0.0653 - accuracy: 0.9804 - val_loss: 0.1633 - val_accuracy: 0.9581 - 1s/epoch - 6ms/step
# Epoch 51/101
# 240/240 - 3s - loss: 0.0640 - accuracy: 0.9799 - val_loss: 0.1472 - val_accuracy: 0.9614 - 3s/epoch - 11ms/step
# Epoch 52/101
# 240/240 - 2s - loss: 0.0606 - accuracy: 0.9806 - val_loss: 0.1749 - val_accuracy: 0.9544 - 2s/epoch - 7ms/step
# Epoch 53/101
# 240/240 - 2s - loss: 0.0612 - accuracy: 0.9805 - val_loss: 0.1386 - val_accuracy: 0.9682 - 2s/epoch - 9ms/step
# Epoch 54/101
# 240/240 - 2s - loss: 0.0587 - accuracy: 0.9815 - val_loss: 0.1796 - val_accuracy: 0.9567 - 2s/epoch - 9ms/step
# Epoch 55/101
# 240/240 - 2s - loss: 0.0557 - accuracy: 0.9821 - val_loss: 0.1357 - val_accuracy: 0.9647 - 2s/epoch - 10ms/step
# Epoch 56/101
# 240/240 - 2s - loss: 0.0545 - accuracy: 0.9823 - val_loss: 0.1311 - val_accuracy: 0.9668 - 2s/epoch - 7ms/step
# Epoch 57/101
# 240/240 - 2s - loss: 0.0519 - accuracy: 0.9838 - val_loss: 0.1321 - val_accuracy: 0.9694 - 2s/epoch - 7ms/step
# Epoch 58/101
# 240/240 - 2s - loss: 0.0502 - accuracy: 0.9842 - val_loss: 0.1483 - val_accuracy: 0.9641 - 2s/epoch - 7ms/step
# Epoch 59/101
# 240/240 - 2s - loss: 0.0491 - accuracy: 0.9851 - val_loss: 0.1371 - val_accuracy: 0.9668 - 2s/epoch - 7ms/step
# Epoch 60/101
# 240/240 - 2s - loss: 0.0463 - accuracy: 0.9847 - val_loss: 0.1552 - val_accuracy: 0.9643 - 2s/epoch - 6ms/step
# Epoch 61/101
# 240/240 - 3s - loss: 0.0448 - accuracy: 0.9854 - val_loss: 0.1286 - val_accuracy: 0.9678 - 3s/epoch - 12ms/step
# Epoch 62/101
# 240/240 - 1s - loss: 0.0419 - accuracy: 0.9864 - val_loss: 0.1714 - val_accuracy: 0.9619 - 1s/epoch - 6ms/step
# Epoch 63/101
# 240/240 - 2s - loss: 0.0402 - accuracy: 0.9874 - val_loss: 0.2525 - val_accuracy: 0.9482 - 2s/epoch - 6ms/step
# Epoch 64/101
# 240/240 - 2s - loss: 0.0425 - accuracy: 0.9863 - val_loss: 0.1671 - val_accuracy: 0.9638 - 2s/epoch - 6ms/step
# Epoch 65/101
# 240/240 - 2s - loss: 0.0401 - accuracy: 0.9871 - val_loss: 0.2341 - val_accuracy: 0.9488 - 2s/epoch - 7ms/step
# Epoch 66/101
# 240/240 - 2s - loss: 0.0392 - accuracy: 0.9872 - val_loss: 0.1375 - val_accuracy: 0.9703 - 2s/epoch - 7ms/step
# Epoch 67/101
# 240/240 - 2s - loss: 0.0393 - accuracy: 0.9871 - val_loss: 0.1900 - val_accuracy: 0.9600 - 2s/epoch - 7ms/step
# Epoch 68/101
# 240/240 - 1s - loss: 0.0355 - accuracy: 0.9885 - val_loss: 0.1700 - val_accuracy: 0.9659 - 1s/epoch - 6ms/step
# Epoch 69/101
# 240/240 - 1s - loss: 0.0350 - accuracy: 0.9890 - val_loss: 0.1486 - val_accuracy: 0.9662 - 1s/epoch - 6ms/step
# Epoch 70/101
# 240/240 - 2s - loss: 0.0335 - accuracy: 0.9893 - val_loss: 0.1483 - val_accuracy: 0.9699 - 2s/epoch - 7ms/step
# Epoch 71/101
# 240/240 - 3s - loss: 0.0323 - accuracy: 0.9897 - val_loss: 0.2128 - val_accuracy: 0.9603 - 3s/epoch - 11ms/step
# Epoch 72/101
# 240/240 - 2s - loss: 0.0341 - accuracy: 0.9889 - val_loss: 0.1983 - val_accuracy: 0.9551 - 2s/epoch - 6ms/step
# Epoch 73/101
# 240/240 - 2s - loss: 0.0293 - accuracy: 0.9901 - val_loss: 0.1672 - val_accuracy: 0.9668 - 2s/epoch - 7ms/step
# Epoch 74/101
# 240/240 - 2s - loss: 0.0321 - accuracy: 0.9893 - val_loss: 0.2421 - val_accuracy: 0.9532 - 2s/epoch - 6ms/step
# Epoch 75/101
# 240/240 - 1s - loss: 0.0296 - accuracy: 0.9900 - val_loss: 0.1666 - val_accuracy: 0.9657 - 1s/epoch - 6ms/step
# Epoch 76/101
# 240/240 - 2s - loss: 0.0299 - accuracy: 0.9904 - val_loss: 0.1654 - val_accuracy: 0.9663 - 2s/epoch - 6ms/step
# Epoch 77/101
# 240/240 - 1s - loss: 0.0288 - accuracy: 0.9904 - val_loss: 0.1927 - val_accuracy: 0.9642 - 1s/epoch - 6ms/step
# Epoch 78/101
# 240/240 - 2s - loss: 0.0278 - accuracy: 0.9903 - val_loss: 0.2117 - val_accuracy: 0.9582 - 2s/epoch - 8ms/step
# Epoch 79/101
# 240/240 - 2s - loss: 0.0279 - accuracy: 0.9913 - val_loss: 0.1785 - val_accuracy: 0.9655 - 2s/epoch - 7ms/step
# Epoch 80/101
# 240/240 - 2s - loss: 0.0268 - accuracy: 0.9910 - val_loss: 0.2028 - val_accuracy: 0.9663 - 2s/epoch - 7ms/step
# Epoch 81/101
# 240/240 - 3s - loss: 0.0251 - accuracy: 0.9920 - val_loss: 0.1652 - val_accuracy: 0.9711 - 3s/epoch - 12ms/step
# Epoch 82/101
# 240/240 - 2s - loss: 0.0270 - accuracy: 0.9910 - val_loss: 0.1763 - val_accuracy: 0.9622 - 2s/epoch - 7ms/step
# Epoch 83/101
# 240/240 - 2s - loss: 0.0242 - accuracy: 0.9924 - val_loss: 0.2312 - val_accuracy: 0.9591 - 2s/epoch - 7ms/step
# Epoch 84/101
# 240/240 - 2s - loss: 0.0242 - accuracy: 0.9921 - val_loss: 0.2690 - val_accuracy: 0.9543 - 2s/epoch - 7ms/step
# Epoch 85/101
# 240/240 - 2s - loss: 0.0244 - accuracy: 0.9921 - val_loss: 0.2171 - val_accuracy: 0.9636 - 2s/epoch - 6ms/step
# Epoch 86/101
# 240/240 - 1s - loss: 0.0200 - accuracy: 0.9936 - val_loss: 0.1831 - val_accuracy: 0.9688 - 1s/epoch - 6ms/step
# Epoch 87/101
# 240/240 - 2s - loss: 0.0245 - accuracy: 0.9918 - val_loss: 0.2007 - val_accuracy: 0.9661 - 2s/epoch - 6ms/step
# Epoch 88/101
# 240/240 - 2s - loss: 0.0227 - accuracy: 0.9919 - val_loss: 0.2017 - val_accuracy: 0.9668 - 2s/epoch - 6ms/step
# Epoch 89/101
# 240/240 - 2s - loss: 0.0208 - accuracy: 0.9929 - val_loss: 0.1797 - val_accuracy: 0.9707 - 2s/epoch - 8ms/step
# Epoch 90/101
# 240/240 - 2s - loss: 0.0226 - accuracy: 0.9926 - val_loss: 0.1883 - val_accuracy: 0.9676 - 2s/epoch - 7ms/step
# Epoch 91/101
# 240/240 - 3s - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.2023 - val_accuracy: 0.9699 - 3s/epoch - 13ms/step
# Epoch 92/101
# 240/240 - 1s - loss: 0.0190 - accuracy: 0.9935 - val_loss: 0.1741 - val_accuracy: 0.9705 - 1s/epoch - 6ms/step
# Epoch 93/101
# 240/240 - 1s - loss: 0.0185 - accuracy: 0.9941 - val_loss: 0.2206 - val_accuracy: 0.9653 - 1s/epoch - 6ms/step
# Epoch 94/101
# 240/240 - 1s - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.1983 - val_accuracy: 0.9712 - 1s/epoch - 6ms/step
# Epoch 95/101
# 240/240 - 1s - loss: 0.0203 - accuracy: 0.9936 - val_loss: 0.1936 - val_accuracy: 0.9663 - 1s/epoch - 6ms/step
# Epoch 96/101
# 240/240 - 2s - loss: 0.0188 - accuracy: 0.9932 - val_loss: 0.2176 - val_accuracy: 0.9668 - 2s/epoch - 6ms/step
# Epoch 97/101
# 240/240 - 2s - loss: 0.0190 - accuracy: 0.9939 - val_loss: 0.2328 - val_accuracy: 0.9643 - 2s/epoch - 6ms/step
# Epoch 98/101
# 240/240 - 2s - loss: 0.0196 - accuracy: 0.9933 - val_loss: 0.2184 - val_accuracy: 0.9640 - 2s/epoch - 9ms/step
# Epoch 99/101
# 240/240 - 2s - loss: 0.0192 - accuracy: 0.9937 - val_loss: 0.1841 - val_accuracy: 0.9703 - 2s/epoch - 7ms/step
# Epoch 100/101
# 240/240 - 2s - loss: 0.0172 - accuracy: 0.9944 - val_loss: 0.2016 - val_accuracy: 0.9690 - 2s/epoch - 9ms/step
# Epoch 101/101
# 240/240 - 3s - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.1853 - val_accuracy: 0.9714 - 3s/epoch - 13ms/step

# %%
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2) 
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
# Out:
# 1875/1875 - 3s - loss: 0.0449 - accuracy: 0.9916 - 3s/epoch - 2ms/step
# 313/313 - 1s - loss: 9217.6934 - accuracy: 0.3943 - 660ms/epoch - 2ms/step

# %%
#######################################

# %%
#4: build a model without regularization
act = "relu"
init = "he_uniform"
n = 100
model = tf.keras.Sequential()
model.add(tf.keras.layers. Flatten (input_shape=(28, 28)))
model.add(tf.keras. layers. Dense (units=n, activation=act, kernel_initializer = init)) 
model.add(tf.keras.layers. Dense (units=n, activation=act, kernel_initializer = init)) 
model.add(tf.keras.layers.Dense (units=10, activation='softmax'))
model.summary()

#4-1: configure the model for training
opt = 'rmsprop' # tf.keras.optimizers.RMSprop (learning_rate=0.001) 
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

#4-2: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=101, batch_size=400,
                validation_data = (x_test, y_test), verbose=0)

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2) 
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)

#4-3: plot accuracies
# plt.title("Without regularization by %s traing data in mnist"%n_sample)
plt.plot(ret.history['accuracy'], "b-", label="train accuracy")
plt.plot(ret.history['val_accuracy'], "r-", label="val accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt. legend (loc="best") 
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_14 (Dense)            (None, 100)               78500
#
#  dense_15 (Dense)            (None, 100)               10100
#
#  dense_16 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 89610 (350.04 KB)
# Trainable params: 89610 (350.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 1875/1875 - 3s - loss: 2.1872e-05 - accuracy: 1.0000 - 3s/epoch - 2ms/step
# 313/313 - 0s - loss: 33.7337 - accuracy: 0.9782 - 456ms/epoch - 1ms/step

# %%
#5: build a model with weight regularization
reg= tf.keras.regularizers.l2(0.01) # L2: 0.01, 0.1, 0.5 
model2 = tf.keras. Sequential()
model2.add(tf.keras.layers. Flatten (input_shape=(28, 28)))
model2.add(tf.keras.layers.Dense (units=n, activation=act, kernel_initializer = init,kernel_regularizer=reg))
model2.add(tf.keras. layers. Dense (units=n, activation=act, kernel_initializer = init,kernel_regularizer=reg))
model2.add(tf.keras. layers. Dense (units=10, activation='softmax'))

##model2.summary()
#5-1: configure the model for training
model2.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

#5-2: train and evaluate the model
ret2 = model2. fit (x_train, y_train, epochs=201, batch_size=400,
                    validation_data = (x_test, y_test), verbose=0) 

train_loss2, train_acc2 = model2.evaluate(x_train, y_train, verbose=2) 
test_loss2, test_acc2 = model2.evaluate(x_test, y_test, verbose=2)
#5-3: plot accuracy
# plt.title("With regularization by %s traing data in mnist" %n_sample) 
plt.plot(ret2.history['accuracy'],"b-", label="train accuracy") 
plt.plot(ret2. history['val_accuracy'], "r-", label="val accuracy") 
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend (loc="best")
plt.show()
# Out:
# 1875/1875 - 3s - loss: 0.1671 - accuracy: 0.9761 - 3s/epoch - 2ms/step
# 313/313 - 0s - loss: 25.8395 - accuracy: 0.8422 - 477ms/epoch - 2ms/step

# %%
#5: build a model with weight regularization
reg= tf.keras.regularizers.l2(0.1) # L2: 0.01, 0.1, 0.5 
model2 = tf.keras. Sequential()
model2.add(tf.keras.layers. Flatten (input_shape=(28, 28)))
model2.add(tf.keras.layers.Dense (units=n, activation=act, kernel_initializer = init,kernel_regularizer=reg))
model2.add(tf.keras. layers. Dense (units=n, activation=act, kernel_initializer = init,kernel_regularizer=reg))
model2.add(tf.keras. layers. Dense (units=10, activation='softmax'))

##model2.summary()
#5-1: configure the model for training
model2.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

#5-2: train and evaluate the model
ret2 = model2. fit (x_train, y_train, epochs=201, batch_size=400,
                    validation_data = (x_test, y_test), verbose=0) 

train_loss2, train_acc2 = model2.evaluate(x_train, y_train, verbose=2) 
test_loss2, test_acc2 = model2.evaluate(x_test, y_test, verbose=2)
#5-3: plot accuracy
# plt.title("With regularization by %s traing data in mnist" %n_sample) 
plt.plot(ret2.history['accuracy'],"b-", label="train accuracy") 
plt.plot(ret2. history['val_accuracy'], "r-", label="val accuracy") 
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend (loc="best")
plt.show()
# Out:
# 1875/1875 - 5s - loss: 0.4889 - accuracy: 0.9071 - 5s/epoch - 3ms/step
# 313/313 - 1s - loss: 48.6138 - accuracy: 0.6750 - 782ms/epoch - 2ms/step

# %%
#5: build a model with weight regularization
reg= tf.keras.regularizers.l2(0.5) # L2: 0.01, 0.1, 0.5 
model2 = tf.keras. Sequential()
model2.add(tf.keras.layers. Flatten (input_shape=(28, 28)))
model2.add(tf.keras.layers.Dense (units=n, activation=act, kernel_initializer = init,kernel_regularizer=reg))
model2.add(tf.keras. layers. Dense (units=n, activation=act, kernel_initializer = init,kernel_regularizer=reg))
model2.add(tf.keras. layers. Dense (units=10, activation='softmax'))

##model2.summary()
#5-1: configure the model for training
model2.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

#5-2: train and evaluate the model
ret2 = model2. fit (x_train, y_train, epochs=201, batch_size=400,
                    validation_data = (x_test, y_test), verbose=0) 

train_loss2, train_acc2 = model2.evaluate(x_train, y_train, verbose=2) 
test_loss2, test_acc2 = model2.evaluate(x_test, y_test, verbose=2)
#5-3: plot accuracy
# plt.title("With regularization by %s traing data in mnist" %n_sample) 
plt.plot(ret2.history['accuracy'],"b-", label="train accuracy") 
plt.plot(ret2. history['val_accuracy'], "r-", label="val accuracy") 
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend (loc="best")
plt.show()
# Out:
# 1875/1875 - 5s - loss: 0.9552 - accuracy: 0.7782 - 5s/epoch - 3ms/step
# 313/313 - 1s - loss: 34.0058 - accuracy: 0.3571 - 911ms/epoch - 3ms/step

# %%
n = 100
dropout_rate=0.2 # 0.5
model= tf.keras. Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer = init)) 
model.add(tf.keras.layers.Dropout(rate=dropout_rate))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer = init)) 
model.add(tf.keras.layers.Dropout(rate=dropout_rate))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.summary()

#4-1: configure the model for training
##opt = tf.keras.optimizers. RMS prop (learning_rate=0.01)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

#4-2: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=201, batch_size=400,
                validation_data = (x_test, y_test), verbose=0)
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2) 
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)

#4-3: plot accuracies
# plt.title("Dropout rate = %s, %s traing data in mnist" % (dropout_rate, n_sample)) 
plt.plot(ret.history['accuracy'], "b-", label="train accuracy")
plt.plot(ret.history['val_accuracy'], "r-", label="val accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(loc="best")
plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 784)               0
#
#  dense_29 (Dense)            (None, 100)               78500
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_30 (Dense)            (None, 100)               10100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_31 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 89610 (350.04 KB)
# Trainable params: 89610 (350.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 1875/1875 - 8s - loss: 4.5633e-04 - accuracy: 0.9999 - 8s/epoch - 4ms/step
# 313/313 - 1s - loss: 53.4263 - accuracy: 0.9763 - 803ms/epoch - 3ms/step

# %%
n = 100
dropout_rate=0.5 # 0.5
model= tf.keras. Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer = init)) 
model.add(tf.keras.layers.Dropout(rate=dropout_rate))
model.add(tf.keras.layers.Dense(units=n, activation=act, kernel_initializer = init)) 
model.add(tf.keras.layers.Dropout(rate=dropout_rate))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
model.summary()

#4-1: configure the model for training
##opt = tf.keras.optimizers. RMS prop (learning_rate=0.01)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

#4-2: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=201, batch_size=400,
                validation_data = (x_test, y_test), verbose=0)
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2) 
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)

#4-3: plot accuracies
# plt.title("Dropout rate = %s, %s traing data in mnist" % (dropout_rate, n_sample)) 
plt.plot(ret.history['accuracy'], "b-", label="train accuracy")
plt.plot(ret.history['val_accuracy'], "r-", label="val accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(loc="best")
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_8 (Flatten)         (None, 784)               0
#
#  dense_32 (Dense)            (None, 100)               78500
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_33 (Dense)            (None, 100)               10100
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_34 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 89610 (350.04 KB)
# Trainable params: 89610 (350.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 1875/1875 - 4s - loss: 0.0147 - accuracy: 0.9959 - 4s/epoch - 2ms/step
# 313/313 - 1s - loss: 101.0503 - accuracy: 0.9622 - 653ms/epoch - 2ms/step

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist 
import numpy as np
import matplotlib.pyplot as plt 
import datetime
#1
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
#2: normalize images
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.0 # [0, 1]
x_test / 255.0

#3: one-hot encoding
y_train = tf.keras.utils.to_categorical (y_train) # (60000, 10) 
y_test = tf.keras.utils.to_categorical (y_test) # (10000, 10)

# %%
#4: build a model with dropout
act = tf.keras. layers. LeakyReLU (alpha=0.3) #' relu', 'sigmoid' 
init = 'he_uniform'
n = 100

dropout_rate= 0.2 # 0.5
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(32, 32, 3)))
model.add(tf.keras. layers.Dense(units=n, activation=act, kernel_initializer = init)) 
model.add(tf.keras. layers.Dropout(rate=dropout_rate))
model.add(tf.keras. layers.Dense(units=n, activation=act, kernel_initializer = init)) 
model.add(tf.keras. layers.Dropout(rate=dropout_rate))
model.add(tf.keras. layers.Dense(units=10, activation='softmax')) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 100)               307300
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 318410 (1.21 MB)
# Trainable params: 318410 (1.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# !pip install pydot
from keras.utils import plot_model
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
#4-1: configure the model for training
opt = tf.keras.optimizers.RMSprop(learning_rate=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

#4-2: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=201, batch_size=400,
                validation_data = (x_test, y_test), verbose=2)
# Out:
# Epoch 1/201
# 125/125 - 3s - loss: 2.6009 - accuracy: 0.1824 - val_loss: 121.0120 - val_accuracy: 0.2849 - 3s/epoch - 25ms/step
# Epoch 2/201
# 125/125 - 2s - loss: 2.1347 - accuracy: 0.2443 - val_loss: 158.5819 - val_accuracy: 0.2503 - 2s/epoch - 18ms/step
# Epoch 3/201
# 125/125 - 2s - loss: 2.0394 - accuracy: 0.2711 - val_loss: 125.3895 - val_accuracy: 0.3332 - 2s/epoch - 17ms/step
# Epoch 4/201
# 125/125 - 2s - loss: 1.9770 - accuracy: 0.2934 - val_loss: 123.4364 - val_accuracy: 0.3518 - 2s/epoch - 16ms/step
# Epoch 5/201
# 125/125 - 3s - loss: 1.9305 - accuracy: 0.3123 - val_loss: 171.8050 - val_accuracy: 0.3368 - 3s/epoch - 21ms/step
# Epoch 6/201
# 125/125 - 3s - loss: 1.8937 - accuracy: 0.3304 - val_loss: 190.1441 - val_accuracy: 0.3217 - 3s/epoch - 21ms/step
# Epoch 7/201
# 125/125 - 3s - loss: 1.8570 - accuracy: 0.3347 - val_loss: 153.6822 - val_accuracy: 0.3724 - 3s/epoch - 23ms/step
# Epoch 8/201
# 125/125 - 3s - loss: 1.8281 - accuracy: 0.3505 - val_loss: 172.4455 - val_accuracy: 0.3577 - 3s/epoch - 22ms/step
# Epoch 9/201
# 125/125 - 3s - loss: 1.8054 - accuracy: 0.3583 - val_loss: 122.4122 - val_accuracy: 0.4184 - 3s/epoch - 23ms/step
# Epoch 10/201
# 125/125 - 2s - loss: 1.7758 - accuracy: 0.3690 - val_loss: 151.0952 - val_accuracy: 0.4006 - 2s/epoch - 20ms/step
# Epoch 11/201
# 125/125 - 2s - loss: 1.7569 - accuracy: 0.3769 - val_loss: 181.5472 - val_accuracy: 0.3828 - 2s/epoch - 18ms/step
# Epoch 12/201
# 125/125 - 2s - loss: 1.7379 - accuracy: 0.3829 - val_loss: 234.4317 - val_accuracy: 0.3441 - 2s/epoch - 18ms/step
# Epoch 13/201
# 125/125 - 2s - loss: 1.7203 - accuracy: 0.3927 - val_loss: 168.0872 - val_accuracy: 0.4047 - 2s/epoch - 17ms/step
# Epoch 14/201
# 125/125 - 2s - loss: 1.7045 - accuracy: 0.3963 - val_loss: 136.5325 - val_accuracy: 0.4353 - 2s/epoch - 17ms/step
# Epoch 15/201
# 125/125 - 2s - loss: 1.6847 - accuracy: 0.4041 - val_loss: 154.5745 - val_accuracy: 0.4059 - 2s/epoch - 17ms/step
# Epoch 16/201
# 125/125 - 2s - loss: 1.6748 - accuracy: 0.4078 - val_loss: 228.3892 - val_accuracy: 0.3593 - 2s/epoch - 16ms/step
# Epoch 17/201
# 125/125 - 2s - loss: 1.6674 - accuracy: 0.4117 - val_loss: 155.4937 - val_accuracy: 0.4328 - 2s/epoch - 18ms/step
# Epoch 18/201
# 125/125 - 2s - loss: 1.6547 - accuracy: 0.4125 - val_loss: 165.7823 - val_accuracy: 0.4215 - 2s/epoch - 16ms/step
# Epoch 19/201
# 125/125 - 2s - loss: 1.6401 - accuracy: 0.4170 - val_loss: 162.0334 - val_accuracy: 0.4342 - 2s/epoch - 17ms/step
# Epoch 20/201
# 125/125 - 2s - loss: 1.6360 - accuracy: 0.4223 - val_loss: 162.7959 - val_accuracy: 0.4238 - 2s/epoch - 16ms/step
# Epoch 21/201
# 125/125 - 2s - loss: 1.6253 - accuracy: 0.4250 - val_loss: 170.2589 - val_accuracy: 0.4355 - 2s/epoch - 16ms/step
# Epoch 22/201
# 125/125 - 2s - loss: 1.6208 - accuracy: 0.4277 - val_loss: 157.7019 - val_accuracy: 0.4320 - 2s/epoch - 18ms/step
# Epoch 23/201
# 125/125 - 2s - loss: 1.6099 - accuracy: 0.4321 - val_loss: 167.1405 - val_accuracy: 0.4193 - 2s/epoch - 17ms/step
# Epoch 24/201
# 125/125 - 2s - loss: 1.5988 - accuracy: 0.4357 - val_loss: 133.2911 - val_accuracy: 0.4612 - 2s/epoch - 18ms/step
# Epoch 25/201
# 125/125 - 2s - loss: 1.5939 - accuracy: 0.4364 - val_loss: 153.7386 - val_accuracy: 0.4380 - 2s/epoch - 17ms/step
# Epoch 26/201
# 125/125 - 2s - loss: 1.5864 - accuracy: 0.4391 - val_loss: 176.5414 - val_accuracy: 0.4346 - 2s/epoch - 17ms/step
# Epoch 27/201
# 125/125 - 2s - loss: 1.5833 - accuracy: 0.4383 - val_loss: 159.9832 - val_accuracy: 0.4493 - 2s/epoch - 19ms/step
# Epoch 28/201
# 125/125 - 2s - loss: 1.5742 - accuracy: 0.4413 - val_loss: 181.5374 - val_accuracy: 0.4250 - 2s/epoch - 18ms/step
# Epoch 29/201
# 125/125 - 2s - loss: 1.5700 - accuracy: 0.4449 - val_loss: 240.1703 - val_accuracy: 0.3717 - 2s/epoch - 18ms/step
# Epoch 30/201
# 125/125 - 3s - loss: 1.5673 - accuracy: 0.4471 - val_loss: 186.4369 - val_accuracy: 0.4179 - 3s/epoch - 21ms/step
# Epoch 31/201
# 125/125 - 3s - loss: 1.5615 - accuracy: 0.4493 - val_loss: 180.1127 - val_accuracy: 0.4370 - 3s/epoch - 25ms/step
# Epoch 32/201
# 125/125 - 2s - loss: 1.5538 - accuracy: 0.4524 - val_loss: 241.8961 - val_accuracy: 0.4015 - 2s/epoch - 19ms/step
# Epoch 33/201
# 125/125 - 2s - loss: 1.5552 - accuracy: 0.4498 - val_loss: 175.9019 - val_accuracy: 0.4360 - 2s/epoch - 18ms/step
# Epoch 34/201
# 125/125 - 3s - loss: 1.5482 - accuracy: 0.4510 - val_loss: 159.6176 - val_accuracy: 0.4486 - 3s/epoch - 22ms/step
# Epoch 35/201
# 125/125 - 3s - loss: 1.5451 - accuracy: 0.4531 - val_loss: 197.4286 - val_accuracy: 0.4182 - 3s/epoch - 21ms/step
# Epoch 36/201
# 125/125 - 3s - loss: 1.5411 - accuracy: 0.4539 - val_loss: 188.8153 - val_accuracy: 0.4316 - 3s/epoch - 23ms/step
# Epoch 37/201
# 125/125 - 3s - loss: 1.5390 - accuracy: 0.4568 - val_loss: 176.3275 - val_accuracy: 0.4395 - 3s/epoch - 25ms/step
# Epoch 38/201
# 125/125 - 2s - loss: 1.5287 - accuracy: 0.4601 - val_loss: 171.6037 - val_accuracy: 0.4465 - 2s/epoch - 19ms/step
# Epoch 39/201
# 125/125 - 2s - loss: 1.5250 - accuracy: 0.4599 - val_loss: 188.2020 - val_accuracy: 0.4385 - 2s/epoch - 17ms/step
# Epoch 40/201
# 125/125 - 2s - loss: 1.5210 - accuracy: 0.4627 - val_loss: 172.7422 - val_accuracy: 0.4522 - 2s/epoch - 19ms/step
# Epoch 41/201
# 125/125 - 2s - loss: 1.5203 - accuracy: 0.4634 - val_loss: 229.9866 - val_accuracy: 0.4000 - 2s/epoch - 17ms/step
# Epoch 42/201
# 125/125 - 2s - loss: 1.5206 - accuracy: 0.4628 - val_loss: 237.5847 - val_accuracy: 0.3895 - 2s/epoch - 18ms/step
# Epoch 43/201
# 125/125 - 2s - loss: 1.5090 - accuracy: 0.4655 - val_loss: 194.0747 - val_accuracy: 0.4233 - 2s/epoch - 18ms/step
# Epoch 44/201
# 125/125 - 2s - loss: 1.5076 - accuracy: 0.4645 - val_loss: 184.9570 - val_accuracy: 0.4439 - 2s/epoch - 18ms/step
# Epoch 45/201
# 125/125 - 2s - loss: 1.5020 - accuracy: 0.4685 - val_loss: 180.7662 - val_accuracy: 0.4446 - 2s/epoch - 19ms/step
# Epoch 46/201
# 125/125 - 2s - loss: 1.5011 - accuracy: 0.4709 - val_loss: 181.8261 - val_accuracy: 0.4518 - 2s/epoch - 16ms/step
# Epoch 47/201
# 125/125 - 2s - loss: 1.5006 - accuracy: 0.4675 - val_loss: 220.2252 - val_accuracy: 0.4073 - 2s/epoch - 19ms/step
# Epoch 48/201
# 125/125 - 2s - loss: 1.4949 - accuracy: 0.4698 - val_loss: 200.2044 - val_accuracy: 0.4340 - 2s/epoch - 17ms/step
# Epoch 49/201
# 125/125 - 2s - loss: 1.4897 - accuracy: 0.4758 - val_loss: 203.4061 - val_accuracy: 0.4385 - 2s/epoch - 20ms/step
# Epoch 50/201
# 125/125 - 2s - loss: 1.4903 - accuracy: 0.4703 - val_loss: 192.4738 - val_accuracy: 0.4537 - 2s/epoch - 19ms/step
# Epoch 51/201
# 125/125 - 2s - loss: 1.4885 - accuracy: 0.4740 - val_loss: 199.1024 - val_accuracy: 0.4422 - 2s/epoch - 19ms/step
# Epoch 52/201
# 125/125 - 2s - loss: 1.4810 - accuracy: 0.4751 - val_loss: 196.1005 - val_accuracy: 0.4320 - 2s/epoch - 17ms/step
# Epoch 53/201
# 125/125 - 2s - loss: 1.4802 - accuracy: 0.4753 - val_loss: 204.7619 - val_accuracy: 0.4256 - 2s/epoch - 19ms/step
# Epoch 54/201
# 125/125 - 2s - loss: 1.4834 - accuracy: 0.4751 - val_loss: 177.2946 - val_accuracy: 0.4431 - 2s/epoch - 19ms/step
# Epoch 55/201
# 125/125 - 2s - loss: 1.4746 - accuracy: 0.4762 - val_loss: 233.2634 - val_accuracy: 0.4229 - 2s/epoch - 17ms/step
# Epoch 56/201
# 125/125 - 2s - loss: 1.4773 - accuracy: 0.4747 - val_loss: 186.9260 - val_accuracy: 0.4567 - 2s/epoch - 18ms/step
# Epoch 57/201
# 125/125 - 2s - loss: 1.4668 - accuracy: 0.4804 - val_loss: 209.1274 - val_accuracy: 0.4380 - 2s/epoch - 17ms/step
# Epoch 58/201
# 125/125 - 3s - loss: 1.4687 - accuracy: 0.4790 - val_loss: 254.9773 - val_accuracy: 0.4051 - 3s/epoch - 22ms/step
# Epoch 59/201
# 125/125 - 3s - loss: 1.4659 - accuracy: 0.4821 - val_loss: 214.0927 - val_accuracy: 0.4249 - 3s/epoch - 25ms/step
# Epoch 60/201
# 125/125 - 2s - loss: 1.4643 - accuracy: 0.4818 - val_loss: 175.2935 - val_accuracy: 0.4503 - 2s/epoch - 19ms/step
# Epoch 61/201
# 125/125 - 2s - loss: 1.4610 - accuracy: 0.4835 - val_loss: 210.7699 - val_accuracy: 0.4368 - 2s/epoch - 18ms/step
# Epoch 62/201
# 125/125 - 2s - loss: 1.4636 - accuracy: 0.4819 - val_loss: 224.9413 - val_accuracy: 0.4225 - 2s/epoch - 19ms/step
# Epoch 63/201
# 125/125 - 2s - loss: 1.4541 - accuracy: 0.4845 - val_loss: 193.2375 - val_accuracy: 0.4429 - 2s/epoch - 17ms/step
# Epoch 64/201
# 125/125 - 2s - loss: 1.4545 - accuracy: 0.4864 - val_loss: 188.3058 - val_accuracy: 0.4558 - 2s/epoch - 17ms/step
# Epoch 65/201
# 125/125 - 2s - loss: 1.4485 - accuracy: 0.4887 - val_loss: 225.0931 - val_accuracy: 0.4223 - 2s/epoch - 18ms/step
# Epoch 66/201
# 125/125 - 2s - loss: 1.4528 - accuracy: 0.4855 - val_loss: 210.7127 - val_accuracy: 0.4240 - 2s/epoch - 15ms/step
# Epoch 67/201
# 125/125 - 2s - loss: 1.4485 - accuracy: 0.4885 - val_loss: 198.2591 - val_accuracy: 0.4379 - 2s/epoch - 17ms/step
# Epoch 68/201
# 125/125 - 2s - loss: 1.4495 - accuracy: 0.4850 - val_loss: 245.4207 - val_accuracy: 0.4108 - 2s/epoch - 19ms/step
# Epoch 69/201
# 125/125 - 2s - loss: 1.4450 - accuracy: 0.4891 - val_loss: 194.0747 - val_accuracy: 0.4475 - 2s/epoch - 17ms/step
# Epoch 70/201
# 125/125 - 2s - loss: 1.4439 - accuracy: 0.4875 - val_loss: 213.6579 - val_accuracy: 0.4363 - 2s/epoch - 17ms/step
# Epoch 71/201
# 125/125 - 2s - loss: 1.4387 - accuracy: 0.4880 - val_loss: 204.8938 - val_accuracy: 0.4462 - 2s/epoch - 17ms/step
# Epoch 72/201
# 125/125 - 2s - loss: 1.4412 - accuracy: 0.4876 - val_loss: 215.2370 - val_accuracy: 0.4284 - 2s/epoch - 19ms/step
# Epoch 73/201
# 125/125 - 2s - loss: 1.4385 - accuracy: 0.4881 - val_loss: 216.3311 - val_accuracy: 0.4420 - 2s/epoch - 18ms/step
# Epoch 74/201
# 125/125 - 3s - loss: 1.4300 - accuracy: 0.4921 - val_loss: 201.9465 - val_accuracy: 0.4432 - 3s/epoch - 25ms/step
# Epoch 75/201
# 125/125 - 3s - loss: 1.4292 - accuracy: 0.4961 - val_loss: 244.8713 - val_accuracy: 0.4154 - 3s/epoch - 28ms/step
# Epoch 76/201
# 125/125 - 2s - loss: 1.4278 - accuracy: 0.4932 - val_loss: 199.3722 - val_accuracy: 0.4376 - 2s/epoch - 17ms/step
# Epoch 77/201
# 125/125 - 2s - loss: 1.4294 - accuracy: 0.4942 - val_loss: 211.7750 - val_accuracy: 0.4333 - 2s/epoch - 17ms/step
# Epoch 78/201
# 125/125 - 2s - loss: 1.4281 - accuracy: 0.4951 - val_loss: 218.6258 - val_accuracy: 0.4335 - 2s/epoch - 17ms/step
# Epoch 79/201
# 125/125 - 2s - loss: 1.4266 - accuracy: 0.4932 - val_loss: 231.4274 - val_accuracy: 0.4289 - 2s/epoch - 16ms/step
# Epoch 80/201
# 125/125 - 2s - loss: 1.4188 - accuracy: 0.4966 - val_loss: 218.0611 - val_accuracy: 0.4219 - 2s/epoch - 16ms/step
# Epoch 81/201
# 125/125 - 2s - loss: 1.4212 - accuracy: 0.4957 - val_loss: 251.4275 - val_accuracy: 0.4164 - 2s/epoch - 17ms/step
# Epoch 82/201
# 125/125 - 2s - loss: 1.4194 - accuracy: 0.4975 - val_loss: 202.9895 - val_accuracy: 0.4503 - 2s/epoch - 16ms/step
# Epoch 83/201
# 125/125 - 2s - loss: 1.4236 - accuracy: 0.4953 - val_loss: 243.7285 - val_accuracy: 0.4212 - 2s/epoch - 16ms/step
# Epoch 84/201
# 125/125 - 2s - loss: 1.4199 - accuracy: 0.4961 - val_loss: 227.7018 - val_accuracy: 0.4287 - 2s/epoch - 17ms/step
# Epoch 85/201
# 125/125 - 2s - loss: 1.4145 - accuracy: 0.4994 - val_loss: 207.3347 - val_accuracy: 0.4450 - 2s/epoch - 17ms/step
# Epoch 86/201
# 125/125 - 2s - loss: 1.4211 - accuracy: 0.4956 - val_loss: 234.1690 - val_accuracy: 0.4345 - 2s/epoch - 16ms/step
# Epoch 87/201
# 125/125 - 2s - loss: 1.4107 - accuracy: 0.5013 - val_loss: 227.5703 - val_accuracy: 0.4156 - 2s/epoch - 17ms/step
# Epoch 88/201
# 125/125 - 2s - loss: 1.4142 - accuracy: 0.4960 - val_loss: 264.9183 - val_accuracy: 0.4184 - 2s/epoch - 16ms/step
# Epoch 89/201
# 125/125 - 2s - loss: 1.4091 - accuracy: 0.5041 - val_loss: 212.6505 - val_accuracy: 0.4503 - 2s/epoch - 17ms/step
# Epoch 90/201
# 125/125 - 2s - loss: 1.4123 - accuracy: 0.5000 - val_loss: 207.6224 - val_accuracy: 0.4388 - 2s/epoch - 16ms/step
# Epoch 91/201
# 125/125 - 2s - loss: 1.4115 - accuracy: 0.4977 - val_loss: 213.6443 - val_accuracy: 0.4393 - 2s/epoch - 16ms/step
# Epoch 92/201
# 125/125 - 2s - loss: 1.4030 - accuracy: 0.5026 - val_loss: 224.8114 - val_accuracy: 0.4262 - 2s/epoch - 16ms/step
# Epoch 93/201
# 125/125 - 2s - loss: 1.4083 - accuracy: 0.4999 - val_loss: 233.3618 - val_accuracy: 0.4196 - 2s/epoch - 17ms/step
# Epoch 94/201
# 125/125 - 2s - loss: 1.4052 - accuracy: 0.5022 - val_loss: 239.4955 - val_accuracy: 0.4324 - 2s/epoch - 16ms/step
# Epoch 95/201
# 125/125 - 2s - loss: 1.4028 - accuracy: 0.5016 - val_loss: 242.2001 - val_accuracy: 0.4178 - 2s/epoch - 16ms/step
# Epoch 96/201
# 125/125 - 2s - loss: 1.3993 - accuracy: 0.5037 - val_loss: 219.6781 - val_accuracy: 0.4429 - 2s/epoch - 16ms/step
# Epoch 97/201
# 125/125 - 2s - loss: 1.3986 - accuracy: 0.5039 - val_loss: 266.8207 - val_accuracy: 0.4039 - 2s/epoch - 17ms/step
# Epoch 98/201
# 125/125 - 2s - loss: 1.3987 - accuracy: 0.5051 - val_loss: 201.8651 - val_accuracy: 0.4546 - 2s/epoch - 16ms/step
# Epoch 99/201
# 125/125 - 2s - loss: 1.4003 - accuracy: 0.5022 - val_loss: 275.5484 - val_accuracy: 0.4063 - 2s/epoch - 16ms/step
# Epoch 100/201
# 125/125 - 2s - loss: 1.3957 - accuracy: 0.5061 - val_loss: 229.1904 - val_accuracy: 0.4288 - 2s/epoch - 17ms/step
# Epoch 101/201
# 125/125 - 2s - loss: 1.3964 - accuracy: 0.5044 - val_loss: 198.5685 - val_accuracy: 0.4564 - 2s/epoch - 16ms/step
# Epoch 102/201
# 125/125 - 2s - loss: 1.3948 - accuracy: 0.5039 - val_loss: 238.0750 - val_accuracy: 0.4120 - 2s/epoch - 16ms/step
# Epoch 103/201
# 125/125 - 2s - loss: 1.3963 - accuracy: 0.5050 - val_loss: 236.2623 - val_accuracy: 0.4262 - 2s/epoch - 17ms/step
# Epoch 104/201
# 125/125 - 2s - loss: 1.3847 - accuracy: 0.5089 - val_loss: 232.0637 - val_accuracy: 0.4308 - 2s/epoch - 16ms/step
# Epoch 105/201
# 125/125 - 2s - loss: 1.3929 - accuracy: 0.5053 - val_loss: 213.0179 - val_accuracy: 0.4451 - 2s/epoch - 16ms/step
# Epoch 106/201
# 125/125 - 2s - loss: 1.3864 - accuracy: 0.5109 - val_loss: 257.5176 - val_accuracy: 0.4135 - 2s/epoch - 16ms/step
# Epoch 107/201
# 125/125 - 2s - loss: 1.3914 - accuracy: 0.5073 - val_loss: 239.6801 - val_accuracy: 0.4273 - 2s/epoch - 17ms/step
# Epoch 108/201
# 125/125 - 2s - loss: 1.3843 - accuracy: 0.5090 - val_loss: 227.6238 - val_accuracy: 0.4381 - 2s/epoch - 17ms/step
# Epoch 109/201
# 125/125 - 2s - loss: 1.3781 - accuracy: 0.5088 - val_loss: 236.4137 - val_accuracy: 0.4310 - 2s/epoch - 17ms/step
# Epoch 110/201
# 125/125 - 2s - loss: 1.3888 - accuracy: 0.5104 - val_loss: 204.2998 - val_accuracy: 0.4469 - 2s/epoch - 17ms/step
# Epoch 111/201
# 125/125 - 2s - loss: 1.3816 - accuracy: 0.5088 - val_loss: 230.9726 - val_accuracy: 0.4360 - 2s/epoch - 18ms/step
# Epoch 112/201
# 125/125 - 2s - loss: 1.3796 - accuracy: 0.5101 - val_loss: 319.6529 - val_accuracy: 0.4007 - 2s/epoch - 18ms/step
# Epoch 113/201
# 125/125 - 2s - loss: 1.3838 - accuracy: 0.5073 - val_loss: 217.4962 - val_accuracy: 0.4420 - 2s/epoch - 18ms/step
# Epoch 114/201
# 125/125 - 2s - loss: 1.3796 - accuracy: 0.5099 - val_loss: 224.4046 - val_accuracy: 0.4367 - 2s/epoch - 17ms/step
# Epoch 115/201
# 125/125 - 2s - loss: 1.3751 - accuracy: 0.5121 - val_loss: 246.6570 - val_accuracy: 0.4309 - 2s/epoch - 18ms/step
# Epoch 116/201
# 125/125 - 2s - loss: 1.3761 - accuracy: 0.5128 - val_loss: 264.2748 - val_accuracy: 0.4127 - 2s/epoch - 17ms/step
# Epoch 117/201
# 125/125 - 2s - loss: 1.3797 - accuracy: 0.5151 - val_loss: 210.3120 - val_accuracy: 0.4481 - 2s/epoch - 18ms/step
# Epoch 118/201
# 125/125 - 3s - loss: 1.3712 - accuracy: 0.5148 - val_loss: 232.5800 - val_accuracy: 0.4274 - 3s/epoch - 22ms/step
# Epoch 119/201
# 125/125 - 2s - loss: 1.3770 - accuracy: 0.5127 - val_loss: 256.4625 - val_accuracy: 0.4292 - 2s/epoch - 19ms/step
# Epoch 120/201
# 125/125 - 2s - loss: 1.3730 - accuracy: 0.5114 - val_loss: 257.4054 - val_accuracy: 0.4197 - 2s/epoch - 17ms/step
# Epoch 121/201
# 125/125 - 2s - loss: 1.3695 - accuracy: 0.5147 - val_loss: 220.4422 - val_accuracy: 0.4419 - 2s/epoch - 16ms/step
# Epoch 122/201
# 125/125 - 2s - loss: 1.3670 - accuracy: 0.5168 - val_loss: 266.2997 - val_accuracy: 0.4253 - 2s/epoch - 16ms/step
# Epoch 123/201
# 125/125 - 2s - loss: 1.3669 - accuracy: 0.5182 - val_loss: 252.0541 - val_accuracy: 0.4046 - 2s/epoch - 17ms/step
# Epoch 124/201
# 125/125 - 2s - loss: 1.3674 - accuracy: 0.5169 - val_loss: 226.8490 - val_accuracy: 0.4387 - 2s/epoch - 17ms/step
# Epoch 125/201
# 125/125 - 2s - loss: 1.3672 - accuracy: 0.5162 - val_loss: 203.6469 - val_accuracy: 0.4545 - 2s/epoch - 16ms/step
# Epoch 126/201
# 125/125 - 2s - loss: 1.3656 - accuracy: 0.5140 - val_loss: 260.6032 - val_accuracy: 0.4331 - 2s/epoch - 16ms/step
# Epoch 127/201
# 125/125 - 2s - loss: 1.3645 - accuracy: 0.5158 - val_loss: 197.8361 - val_accuracy: 0.4502 - 2s/epoch - 18ms/step
# Epoch 128/201
# 125/125 - 2s - loss: 1.3648 - accuracy: 0.5130 - val_loss: 256.3808 - val_accuracy: 0.4162 - 2s/epoch - 19ms/step
# Epoch 129/201
# 125/125 - 2s - loss: 1.3638 - accuracy: 0.5138 - val_loss: 232.7603 - val_accuracy: 0.4387 - 2s/epoch - 18ms/step
# Epoch 130/201
# 125/125 - 2s - loss: 1.3656 - accuracy: 0.5145 - val_loss: 273.9724 - val_accuracy: 0.4195 - 2s/epoch - 18ms/step
# Epoch 131/201
# 125/125 - 2s - loss: 1.3630 - accuracy: 0.5156 - val_loss: 245.0266 - val_accuracy: 0.4260 - 2s/epoch - 17ms/step
# Epoch 132/201
# 125/125 - 2s - loss: 1.3649 - accuracy: 0.5142 - val_loss: 213.7460 - val_accuracy: 0.4502 - 2s/epoch - 19ms/step
# Epoch 133/201
# 125/125 - 2s - loss: 1.3583 - accuracy: 0.5182 - val_loss: 214.3489 - val_accuracy: 0.4616 - 2s/epoch - 18ms/step
# Epoch 134/201
# 125/125 - 2s - loss: 1.3543 - accuracy: 0.5171 - val_loss: 253.5374 - val_accuracy: 0.4192 - 2s/epoch - 16ms/step
# Epoch 135/201
# 125/125 - 2s - loss: 1.3574 - accuracy: 0.5213 - val_loss: 250.2535 - val_accuracy: 0.4249 - 2s/epoch - 16ms/step
# Epoch 136/201
# 125/125 - 2s - loss: 1.3610 - accuracy: 0.5164 - val_loss: 223.5896 - val_accuracy: 0.4315 - 2s/epoch - 16ms/step
# Epoch 137/201
# 125/125 - 2s - loss: 1.3549 - accuracy: 0.5163 - val_loss: 254.8946 - val_accuracy: 0.4318 - 2s/epoch - 17ms/step
# Epoch 138/201
# 125/125 - 2s - loss: 1.3525 - accuracy: 0.5175 - val_loss: 225.6658 - val_accuracy: 0.4324 - 2s/epoch - 18ms/step
# Epoch 139/201
# 125/125 - 2s - loss: 1.3529 - accuracy: 0.5193 - val_loss: 254.0947 - val_accuracy: 0.4163 - 2s/epoch - 17ms/step
# Epoch 140/201
# 125/125 - 2s - loss: 1.3550 - accuracy: 0.5194 - val_loss: 241.5450 - val_accuracy: 0.4424 - 2s/epoch - 16ms/step
# Epoch 141/201
# 125/125 - 2s - loss: 1.3508 - accuracy: 0.5220 - val_loss: 261.5148 - val_accuracy: 0.4212 - 2s/epoch - 17ms/step
# Epoch 142/201
# 125/125 - 2s - loss: 1.3514 - accuracy: 0.5205 - val_loss: 284.2338 - val_accuracy: 0.4037 - 2s/epoch - 16ms/step
# Epoch 143/201
# 125/125 - 2s - loss: 1.3521 - accuracy: 0.5209 - val_loss: 239.5269 - val_accuracy: 0.4305 - 2s/epoch - 17ms/step
# Epoch 144/201
# 125/125 - 2s - loss: 1.3546 - accuracy: 0.5186 - val_loss: 254.0883 - val_accuracy: 0.4386 - 2s/epoch - 18ms/step
# Epoch 145/201
# 125/125 - 2s - loss: 1.3516 - accuracy: 0.5218 - val_loss: 236.7059 - val_accuracy: 0.4301 - 2s/epoch - 17ms/step
# Epoch 146/201
# 125/125 - 2s - loss: 1.3506 - accuracy: 0.5224 - val_loss: 235.1589 - val_accuracy: 0.4348 - 2s/epoch - 16ms/step
# Epoch 147/201
# 125/125 - 2s - loss: 1.3464 - accuracy: 0.5212 - val_loss: 232.8503 - val_accuracy: 0.4454 - 2s/epoch - 18ms/step
# Epoch 148/201
# 125/125 - 2s - loss: 1.3501 - accuracy: 0.5195 - val_loss: 240.3654 - val_accuracy: 0.4441 - 2s/epoch - 17ms/step
# Epoch 149/201
# 125/125 - 2s - loss: 1.3454 - accuracy: 0.5199 - val_loss: 308.5338 - val_accuracy: 0.4058 - 2s/epoch - 17ms/step
# Epoch 150/201
# 125/125 - 2s - loss: 1.3496 - accuracy: 0.5201 - val_loss: 266.2787 - val_accuracy: 0.4199 - 2s/epoch - 19ms/step
# Epoch 151/201
# 125/125 - 2s - loss: 1.3381 - accuracy: 0.5243 - val_loss: 279.8423 - val_accuracy: 0.4111 - 2s/epoch - 17ms/step
# Epoch 152/201
# 125/125 - 2s - loss: 1.3410 - accuracy: 0.5216 - val_loss: 253.6831 - val_accuracy: 0.4208 - 2s/epoch - 17ms/step
# Epoch 153/201
# 125/125 - 2s - loss: 1.3441 - accuracy: 0.5217 - val_loss: 209.9161 - val_accuracy: 0.4401 - 2s/epoch - 18ms/step
# Epoch 154/201
# 125/125 - 2s - loss: 1.3473 - accuracy: 0.5241 - val_loss: 260.5394 - val_accuracy: 0.4098 - 2s/epoch - 17ms/step
# Epoch 155/201
# 125/125 - 2s - loss: 1.3464 - accuracy: 0.5246 - val_loss: 242.0512 - val_accuracy: 0.4264 - 2s/epoch - 16ms/step
# Epoch 156/201
# 125/125 - 2s - loss: 1.3374 - accuracy: 0.5223 - val_loss: 276.7659 - val_accuracy: 0.4157 - 2s/epoch - 16ms/step
# Epoch 157/201
# 125/125 - 2s - loss: 1.3441 - accuracy: 0.5223 - val_loss: 237.9164 - val_accuracy: 0.4256 - 2s/epoch - 16ms/step
# Epoch 158/201
# 125/125 - 2s - loss: 1.3402 - accuracy: 0.5241 - val_loss: 249.9926 - val_accuracy: 0.4363 - 2s/epoch - 17ms/step
# Epoch 159/201
# 125/125 - 2s - loss: 1.3353 - accuracy: 0.5273 - val_loss: 290.7469 - val_accuracy: 0.4121 - 2s/epoch - 17ms/step
# Epoch 160/201
# 125/125 - 2s - loss: 1.3425 - accuracy: 0.5223 - val_loss: 283.0190 - val_accuracy: 0.4166 - 2s/epoch - 17ms/step
# Epoch 161/201
# 125/125 - 2s - loss: 1.3351 - accuracy: 0.5264 - val_loss: 248.5853 - val_accuracy: 0.4226 - 2s/epoch - 16ms/step
# Epoch 162/201
# 125/125 - 2s - loss: 1.3312 - accuracy: 0.5284 - val_loss: 282.3386 - val_accuracy: 0.4185 - 2s/epoch - 17ms/step
# Epoch 163/201
# 125/125 - 2s - loss: 1.3341 - accuracy: 0.5252 - val_loss: 259.9345 - val_accuracy: 0.4304 - 2s/epoch - 17ms/step
# Epoch 164/201
# 125/125 - 2s - loss: 1.3302 - accuracy: 0.5277 - val_loss: 266.4920 - val_accuracy: 0.4213 - 2s/epoch - 16ms/step
# Epoch 165/201
# 125/125 - 2s - loss: 1.3369 - accuracy: 0.5238 - val_loss: 306.6134 - val_accuracy: 0.4052 - 2s/epoch - 17ms/step
# Epoch 166/201
# 125/125 - 2s - loss: 1.3278 - accuracy: 0.5278 - val_loss: 251.0177 - val_accuracy: 0.4290 - 2s/epoch - 18ms/step
# Epoch 167/201
# 125/125 - 2s - loss: 1.3326 - accuracy: 0.5256 - val_loss: 265.9241 - val_accuracy: 0.4257 - 2s/epoch - 16ms/step
# Epoch 168/201
# 125/125 - 2s - loss: 1.3359 - accuracy: 0.5244 - val_loss: 241.4869 - val_accuracy: 0.4102 - 2s/epoch - 17ms/step
# Epoch 169/201
# 125/125 - 2s - loss: 1.3286 - accuracy: 0.5278 - val_loss: 280.7214 - val_accuracy: 0.4113 - 2s/epoch - 16ms/step
# Epoch 170/201
# 125/125 - 2s - loss: 1.3289 - accuracy: 0.5277 - val_loss: 223.7700 - val_accuracy: 0.4367 - 2s/epoch - 16ms/step
# Epoch 171/201
# 125/125 - 2s - loss: 1.3249 - accuracy: 0.5286 - val_loss: 271.7140 - val_accuracy: 0.4236 - 2s/epoch - 16ms/step
# Epoch 172/201
# 125/125 - 2s - loss: 1.3291 - accuracy: 0.5284 - val_loss: 240.3344 - val_accuracy: 0.4452 - 2s/epoch - 17ms/step
# Epoch 173/201
# 125/125 - 2s - loss: 1.3329 - accuracy: 0.5265 - val_loss: 261.7399 - val_accuracy: 0.4347 - 2s/epoch - 16ms/step
# Epoch 174/201
# 125/125 - 2s - loss: 1.3285 - accuracy: 0.5303 - val_loss: 312.3710 - val_accuracy: 0.4049 - 2s/epoch - 18ms/step
# Epoch 175/201
# 125/125 - 2s - loss: 1.3245 - accuracy: 0.5279 - val_loss: 271.3457 - val_accuracy: 0.4268 - 2s/epoch - 18ms/step
# Epoch 176/201
# 125/125 - 2s - loss: 1.3227 - accuracy: 0.5305 - val_loss: 258.7839 - val_accuracy: 0.4243 - 2s/epoch - 16ms/step
# Epoch 177/201
# 125/125 - 2s - loss: 1.3262 - accuracy: 0.5289 - val_loss: 245.0214 - val_accuracy: 0.4364 - 2s/epoch - 16ms/step
# Epoch 178/201
# 125/125 - 2s - loss: 1.3267 - accuracy: 0.5259 - val_loss: 260.4788 - val_accuracy: 0.4216 - 2s/epoch - 17ms/step
# Epoch 179/201
# 125/125 - 2s - loss: 1.3194 - accuracy: 0.5302 - val_loss: 292.6508 - val_accuracy: 0.4071 - 2s/epoch - 16ms/step
# Epoch 180/201
# 125/125 - 2s - loss: 1.3232 - accuracy: 0.5300 - val_loss: 247.1143 - val_accuracy: 0.4225 - 2s/epoch - 16ms/step
# Epoch 181/201
# 125/125 - 2s - loss: 1.3189 - accuracy: 0.5320 - val_loss: 290.8218 - val_accuracy: 0.4039 - 2s/epoch - 17ms/step
# Epoch 182/201
# 125/125 - 2s - loss: 1.3229 - accuracy: 0.5307 - val_loss: 266.4779 - val_accuracy: 0.3995 - 2s/epoch - 16ms/step
# Epoch 183/201
# 125/125 - 2s - loss: 1.3211 - accuracy: 0.5329 - val_loss: 316.6920 - val_accuracy: 0.4127 - 2s/epoch - 17ms/step
# Epoch 184/201
# 125/125 - 2s - loss: 1.3238 - accuracy: 0.5324 - val_loss: 237.7297 - val_accuracy: 0.4482 - 2s/epoch - 16ms/step
# Epoch 185/201
# 125/125 - 2s - loss: 1.3216 - accuracy: 0.5299 - val_loss: 239.1104 - val_accuracy: 0.4412 - 2s/epoch - 17ms/step
# Epoch 186/201
# 125/125 - 2s - loss: 1.3178 - accuracy: 0.5322 - val_loss: 271.6385 - val_accuracy: 0.4114 - 2s/epoch - 17ms/step
# Epoch 187/201
# 125/125 - 2s - loss: 1.3169 - accuracy: 0.5301 - val_loss: 275.7310 - val_accuracy: 0.4262 - 2s/epoch - 16ms/step
# Epoch 188/201
# 125/125 - 2s - loss: 1.3214 - accuracy: 0.5318 - val_loss: 235.6454 - val_accuracy: 0.4415 - 2s/epoch - 17ms/step
# Epoch 189/201
# 125/125 - 2s - loss: 1.3192 - accuracy: 0.5291 - val_loss: 260.2568 - val_accuracy: 0.4280 - 2s/epoch - 17ms/step
# Epoch 190/201
# 125/125 - 2s - loss: 1.3147 - accuracy: 0.5322 - val_loss: 261.0612 - val_accuracy: 0.4240 - 2s/epoch - 18ms/step
# Epoch 191/201
# 125/125 - 3s - loss: 1.3165 - accuracy: 0.5328 - val_loss: 227.7921 - val_accuracy: 0.4456 - 3s/epoch - 21ms/step
# Epoch 192/201
# 125/125 - 2s - loss: 1.3171 - accuracy: 0.5332 - val_loss: 303.0280 - val_accuracy: 0.4077 - 2s/epoch - 17ms/step
# Epoch 193/201
# 125/125 - 2s - loss: 1.3122 - accuracy: 0.5327 - val_loss: 289.1625 - val_accuracy: 0.4009 - 2s/epoch - 17ms/step
# Epoch 194/201
# 125/125 - 2s - loss: 1.3168 - accuracy: 0.5313 - val_loss: 241.6302 - val_accuracy: 0.4421 - 2s/epoch - 18ms/step
# Epoch 195/201
# 125/125 - 2s - loss: 1.3118 - accuracy: 0.5346 - val_loss: 278.7516 - val_accuracy: 0.4191 - 2s/epoch - 18ms/step
# Epoch 196/201
# 125/125 - 2s - loss: 1.3195 - accuracy: 0.5302 - val_loss: 223.2478 - val_accuracy: 0.4503 - 2s/epoch - 17ms/step
# Epoch 197/201
# 125/125 - 2s - loss: 1.3111 - accuracy: 0.5339 - val_loss: 248.2702 - val_accuracy: 0.4437 - 2s/epoch - 20ms/step
# Epoch 198/201
# 125/125 - 2s - loss: 1.3143 - accuracy: 0.5338 - val_loss: 242.5908 - val_accuracy: 0.4302 - 2s/epoch - 19ms/step
# Epoch 199/201
# 125/125 - 2s - loss: 1.3152 - accuracy: 0.5334 - val_loss: 269.0227 - val_accuracy: 0.4017 - 2s/epoch - 17ms/step
# Epoch 200/201
# 125/125 - 2s - loss: 1.3155 - accuracy: 0.5338 - val_loss: 243.0943 - val_accuracy: 0.4310 - 2s/epoch - 19ms/step
# Epoch 201/201
# 125/125 - 2s - loss: 1.3109 - accuracy: 0.5354 - val_loss: 249.3578 - val_accuracy: 0.4398 - 2s/epoch - 18ms/step

# %%
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
# Out:
# 1563/1563 - 3s - loss: 1.1273 - accuracy: 0.6018 - 3s/epoch - 2ms/step
# 313/313 - 1s - loss: 249.3577 - accuracy: 0.4398 - 793ms/epoch - 3ms/step

# %%
#4-3: plot accuracies
plt.plot(ret.history['accuracy'], "b-", label="train accuracy")
plt.plot(ret.history['val_accuracy'], "r-", label="val accuracy")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(loc= "best") 
plt.show()
